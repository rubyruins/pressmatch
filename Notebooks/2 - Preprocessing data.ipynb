# %% [markdown]
# ### Load files and libraries

# %%
import pandas as pd
import ftfy
import random
from fake_useragent import UserAgent
import nltk
import pickle
import pandas as pd
from nltk.corpus import wordnet
import json
from afinn import Afinn
import plotly.express as px
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import re
import ftfy
import humanize
import datetime
import langdetect

# %%
articles = pd.read_csv('../Data/articles_v1.csv')

# %%
articles
# Out:
#                      author        date  \
# 0                Aja Styles  2020-12-23
# 1              Jake Johnson  2020-12-23
# 2         Christine Favocci  2020-12-23
# 3       William Rivers Pitt  2020-12-23
# 4               Amy Goodman  2020-12-23
# ...                     ...         ...
# 119946         Daniel Smith  2020-12-05
# 119947       Victoria Jones  2020-12-05
# 119948            Nisha Mal  2020-12-05
# 119949            Nisha Mal  2020-12-05
# 119950       Victoria Jones  2020-12-05
#
#                                               description  \
# 0       Perth mother Clare has found herself mostly co...
# 1       The billâs gifts to the wealthy underscore t...
# 2       It is naive to think that either party is free...
# 3       What Trump may do in his waning days is only u...
# 4       Critics say the $900 billion relief package do...
# ...                                                   ...
# 119946  Ashley Towne decided to get in shape to marry ...
# 119947  Experimenting on the ISS allows scientists to ...
# 119948  All of the properties are Grade I listed build...
# 119949  'It's all one big conundrum,' says Sheila Herbert
# 119950  One customer said a hotel was a 'filthy hovel'...
#
#                                                 full_text  \
# 0        Perth mother Clare* has found herself mostly ...
# 1        In late-night votes just hours after nearly 5...
# 2        The left has insisted that voter fraud is jus...
# 3        The endgame being played out by Donald Trump,...
# 4        As Congress passes a $900 billion coronavirus...
# ...                                                   ...
# 119946   When you subscribe we will use the informatio...
# 119947   When you subscribe we will use the informatio...
# 119948   Three buildings featured in a Jane Austen nov...
# 119949   Woman's home is in Tier 2 while her garden fa...
# 119950   Want the best food, film, music, arts and cul...
#
#                   site_name  \
# 0            Brisbane Times
# 1                  Truthout
# 2       The Western Journal
# 3                  Truthout
# 4                  Truthout
# ...                     ...
# 119946          WalesOnline
# 119947          WalesOnline
# 119948          WalesOnline
# 119949          WalesOnline
# 119950          WalesOnline
#
#                                                     title          topic  \
# 0       'Pack Lego': Perth family caught in hard borde...  entertainment
# 1       Congress Passes COVID Relief With Billions in ...       politics
# 2       PA Man Facing Charges of Unlawful Voting After...           tech
# 3       What Will Trump Attempt in His Last Days? We M...       politics
# 4       The Insufficient COVID Stimulus Must Not Be Fo...       business
# ...                                                   ...            ...
# 119946  'I can't get married looking like this' Rower ...          sport
# 119947  Space experiment could unlock resources for mi...           tech
# 119948  Three buildings featured in a Jane Austen nove...           tech
# 119949  Woman's home is in Tier 2 while her garden fal...           tech
# 119950  Britannia ranked the UK's worst hotel chain fo...           tech
#
#                                                       url  \
# 0       https://www.brisbanetimes.com.au/national/west...
# 1       https://truthout.org/articles/congress-passes-...
# 2       https://www.westernjournal.com/pa-man-facing-c...
# 3       https://truthout.org/articles/what-will-trump-...
# 4       https://truthout.org/video/the-insufficient-co...
# ...                                                   ...
# 119946  https://www.walesonline.co.uk/news/uk-news/i-c...
# 119947  https://www.walesonline.co.uk/news/uk-news/spa...
# 119948  https://www.walesonline.co.uk/news/uk-news/thr...
# 119949  https://www.walesonline.co.uk/news/uk-news/wom...
# 119950  https://www.walesonline.co.uk/whats-on/whats-o...
#
#         author_article_count    author_name_clean
# 0                         14           Aja Styles
# 1                         33         Jake Johnson
# 2                         19    Christine Favocci
# 3                         14  William Rivers Pitt
# 4                         19          Amy Goodman
# ...                      ...                  ...
# 119946                   147         Daniel Smith
# 119947                    92       Victoria Jones
# 119948                    66            Nisha Mal
# 119949                    66            Nisha Mal
# 119950                    92       Victoria Jones
#
# [119951 rows x 10 columns]

# %% [markdown]
# ### Cleaning and preprocessing text columns

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()
tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}

# %%
# Cleaning the text sentences so that punctuation marks, stop words &amp; digits are removed
# Words are lemmatized according to their POS tags
def clean(doc):
    doc = ftfy.fix_text(doc)
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ""
    for word in punc_free.split():
        tag = nltk.pos_tag([word])[0][1][0].upper()
        normalized = normalized + " " + str(lemma.lemmatize(word, tag_dict.get(tag, wordnet.NOUN)))
    processed = re.sub(r"\d+","", normalized)
    y = processed.split()
    return ' '.join(y)

# %% [markdown]
# ### Cleaning article text (title x4, description x2, full_text x1)

# %%
articles = articles.fillna('-')

# %%
articles['content'] = ((articles['title'] + ' ') * 4) + ((articles['description'] + ' ') * 2) + (articles['full_text'])
articles['content'] = articles.apply(lambda x: clean(x['content']), axis = 1)

# %%
articles
# Out:
#                      author        date  \
# 0                Aja Styles  2020-12-23
# 1              Jake Johnson  2020-12-23
# 2         Christine Favocci  2020-12-23
# 3       William Rivers Pitt  2020-12-23
# 4               Amy Goodman  2020-12-23
# ...                     ...         ...
# 119946         Daniel Smith  2020-12-05
# 119947       Victoria Jones  2020-12-05
# 119948            Nisha Mal  2020-12-05
# 119949            Nisha Mal  2020-12-05
# 119950       Victoria Jones  2020-12-05
#
#                                               description  \
# 0       Perth mother Clare has found herself mostly co...
# 1       The billâs gifts to the wealthy underscore t...
# 2       It is naive to think that either party is free...
# 3       What Trump may do in his waning days is only u...
# 4       Critics say the $900 billion relief package do...
# ...                                                   ...
# 119946  Ashley Towne decided to get in shape to marry ...
# 119947  Experimenting on the ISS allows scientists to ...
# 119948  All of the properties are Grade I listed build...
# 119949  'It's all one big conundrum,' says Sheila Herbert
# 119950  One customer said a hotel was a 'filthy hovel'...
#
#                                                 full_text  \
# 0        Perth mother Clare* has found herself mostly ...
# 1        In late-night votes just hours after nearly 5...
# 2        The left has insisted that voter fraud is jus...
# 3        The endgame being played out by Donald Trump,...
# 4        As Congress passes a $900 billion coronavirus...
# ...                                                   ...
# 119946   When you subscribe we will use the informatio...
# 119947   When you subscribe we will use the informatio...
# 119948   Three buildings featured in a Jane Austen nov...
# 119949   Woman's home is in Tier 2 while her garden fa...
# 119950   Want the best food, film, music, arts and cul...
#
#                   site_name  \
# 0            Brisbane Times
# 1                  Truthout
# 2       The Western Journal
# 3                  Truthout
# 4                  Truthout
# ...                     ...
# 119946          WalesOnline
# 119947          WalesOnline
# 119948          WalesOnline
# 119949          WalesOnline
# 119950          WalesOnline
#
#                                                     title          topic  \
# 0       'Pack Lego': Perth family caught in hard borde...  entertainment
# 1       Congress Passes COVID Relief With Billions in ...       politics
# 2       PA Man Facing Charges of Unlawful Voting After...           tech
# 3       What Will Trump Attempt in His Last Days? We M...       politics
# 4       The Insufficient COVID Stimulus Must Not Be Fo...       business
# ...                                                   ...            ...
# 119946  'I can't get married looking like this' Rower ...          sport
# 119947  Space experiment could unlock resources for mi...           tech
# 119948  Three buildings featured in a Jane Austen nove...           tech
# 119949  Woman's home is in Tier 2 while her garden fal...           tech
# 119950  Britannia ranked the UK's worst hotel chain fo...           tech
#
#                                                       url  \
# 0       https://www.brisbanetimes.com.au/national/west...
# 1       https://truthout.org/articles/congress-passes-...
# 2       https://www.westernjournal.com/pa-man-facing-c...
# 3       https://truthout.org/articles/what-will-trump-...
# 4       https://truthout.org/video/the-insufficient-co...
# ...                                                   ...
# 119946  https://www.walesonline.co.uk/news/uk-news/i-c...
# 119947  https://www.walesonline.co.uk/news/uk-news/spa...
# 119948  https://www.walesonline.co.uk/news/uk-news/thr...
# 119949  https://www.walesonline.co.uk/news/uk-news/wom...
# 119950  https://www.walesonline.co.uk/whats-on/whats-o...
#
#         author_article_count    author_name_clean  \
# 0                         14           Aja Styles
# 1                         33         Jake Johnson
# 2                         19    Christine Favocci
# 3                         14  William Rivers Pitt
# 4                         19          Amy Goodman
# ...                      ...                  ...
# 119946                   147         Daniel Smith
# 119947                    92       Victoria Jones
# 119948                    66            Nisha Mal
# 119949                    66            Nisha Mal
# 119950                    92       Victoria Jones
#
#                                                   content
# 0       pack lego perth family caught hard border cros...
# 1       congress pass covid relief billion handout wea...
# 2       pa man face charge unlawful voting allegedly c...
# 3       trump attempt last day must prepare anything t...
# 4       insufficient covid stimulus must follow auster...
# ...                                                   ...
# 119946  i cant get married look like this rower whose ...
# 119947  space experiment could unlock resource mission...
# 119948  three building feature jane austen novel sell ...
# 119949  woman home tier garden fall tier bizarre lockd...
# 119950  britannia ranked uk bad hotel chain eighth yea...
#
# [119951 rows x 11 columns]

# %% [markdown]
# ### Calculating Afinn sentiment for all articles

# %%
afinn = Afinn(language='en')
def get_article_sentiment(text):
    return round(afinn.score(text) / len(text.split()) * 100, 2)

# %%
articles['article_sentiment'] = articles.apply(lambda x: get_article_sentiment(x['full_text']), axis=1)

# %%
articles
# Out:
#                      author        date  \
# 0                Aja Styles  2020-12-23
# 1              Jake Johnson  2020-12-23
# 2         Christine Favocci  2020-12-23
# 3       William Rivers Pitt  2020-12-23
# 4               Amy Goodman  2020-12-23
# ...                     ...         ...
# 119946         Daniel Smith  2020-12-05
# 119947       Victoria Jones  2020-12-05
# 119948            Nisha Mal  2020-12-05
# 119949            Nisha Mal  2020-12-05
# 119950       Victoria Jones  2020-12-05
#
#                                               description  \
# 0       Perth mother Clare has found herself mostly co...
# 1       The billâs gifts to the wealthy underscore t...
# 2       It is naive to think that either party is free...
# 3       What Trump may do in his waning days is only u...
# 4       Critics say the $900 billion relief package do...
# ...                                                   ...
# 119946  Ashley Towne decided to get in shape to marry ...
# 119947  Experimenting on the ISS allows scientists to ...
# 119948  All of the properties are Grade I listed build...
# 119949  'It's all one big conundrum,' says Sheila Herbert
# 119950  One customer said a hotel was a 'filthy hovel'...
#
#                                                 full_text  \
# 0        Perth mother Clare* has found herself mostly ...
# 1        In late-night votes just hours after nearly 5...
# 2        The left has insisted that voter fraud is jus...
# 3        The endgame being played out by Donald Trump,...
# 4        As Congress passes a $900 billion coronavirus...
# ...                                                   ...
# 119946   When you subscribe we will use the informatio...
# 119947   When you subscribe we will use the informatio...
# 119948   Three buildings featured in a Jane Austen nov...
# 119949   Woman's home is in Tier 2 while her garden fa...
# 119950   Want the best food, film, music, arts and cul...
#
#                   site_name  \
# 0            Brisbane Times
# 1                  Truthout
# 2       The Western Journal
# 3                  Truthout
# 4                  Truthout
# ...                     ...
# 119946          WalesOnline
# 119947          WalesOnline
# 119948          WalesOnline
# 119949          WalesOnline
# 119950          WalesOnline
#
#                                                     title          topic  \
# 0       'Pack Lego': Perth family caught in hard borde...  entertainment
# 1       Congress Passes COVID Relief With Billions in ...       politics
# 2       PA Man Facing Charges of Unlawful Voting After...           tech
# 3       What Will Trump Attempt in His Last Days? We M...       politics
# 4       The Insufficient COVID Stimulus Must Not Be Fo...       business
# ...                                                   ...            ...
# 119946  'I can't get married looking like this' Rower ...          sport
# 119947  Space experiment could unlock resources for mi...           tech
# 119948  Three buildings featured in a Jane Austen nove...           tech
# 119949  Woman's home is in Tier 2 while her garden fal...           tech
# 119950  Britannia ranked the UK's worst hotel chain fo...           tech
#
#                                                       url  \
# 0       https://www.brisbanetimes.com.au/national/west...
# 1       https://truthout.org/articles/congress-passes-...
# 2       https://www.westernjournal.com/pa-man-facing-c...
# 3       https://truthout.org/articles/what-will-trump-...
# 4       https://truthout.org/video/the-insufficient-co...
# ...                                                   ...
# 119946  https://www.walesonline.co.uk/news/uk-news/i-c...
# 119947  https://www.walesonline.co.uk/news/uk-news/spa...
# 119948  https://www.walesonline.co.uk/news/uk-news/thr...
# 119949  https://www.walesonline.co.uk/news/uk-news/wom...
# 119950  https://www.walesonline.co.uk/whats-on/whats-o...
#
#         author_article_count    author_name_clean  \
# 0                         14           Aja Styles
# 1                         33         Jake Johnson
# 2                         19    Christine Favocci
# 3                         14  William Rivers Pitt
# 4                         19          Amy Goodman
# ...                      ...                  ...
# 119946                   147         Daniel Smith
# 119947                    92       Victoria Jones
# 119948                    66            Nisha Mal
# 119949                    66            Nisha Mal
# 119950                    92       Victoria Jones
#
#                                                   content  article_sentiment
# 0       pack lego perth family caught hard border cros...               0.00
# 1       congress pass covid relief billion handout wea...              -2.12
# 2       pa man face charge unlawful voting allegedly c...             -16.20
# 3       trump attempt last day must prepare anything t...              -7.61
# 4       insufficient covid stimulus must follow auster...              -0.56
# ...                                                   ...                ...
# 119946  i cant get married look like this rower whose ...               3.09
# 119947  space experiment could unlock resource mission...               6.03
# 119948  three building feature jane austen novel sell ...               3.33
# 119949  woman home tier garden fall tier bizarre lockd...              -2.21
# 119950  britannia ranked uk bad hotel chain eighth yea...              -2.47
#
# [119951 rows x 12 columns]

# %%
articles.describe()
# Out:
#        author_article_count  article_sentiment
# count         119951.000000      119951.000000
# mean              59.786238           1.661658
# std               59.939789           6.624018
# min               10.000000         -47.760000
# 25%               22.000000          -1.850000
# 50%               44.000000           1.890000
# 75%               80.000000           5.580000
# max              523.000000          77.780000

# %%
articles.to_csv('../Data/articles_v2.csv')

# %% [markdown]
# ### Cleaing IAB classifier text

# %%
iab_text = pd.read_csv('../Data/IAB_text_v1.csv')

# %%
iab_text['with_bs4_clean'] = iab_text.apply(lambda x: clean(x['with_bs4']), axis=1)

# %%
iab_text['with_justext_clean'] = iab_text.apply(lambda x: clean(x['with_justext']), axis=1)

# %%
iab_text
# Out:
#       Unique ID Parent        Name  Position  \
# 0             1      -  Automotive         1
# 1             1      -  Automotive         2
# 2             1      -  Automotive         3
# 3             1      -  Automotive         4
# 4             1      -  Automotive         5
# ...         ...    ...         ...       ...
# 11963      1480   1219        City         6
# 11964      1480   1219        City         7
# 11965      1480   1219        City         8
# 11966      1480   1219        City         9
# 11967      1480   1219        City        10
#
#                                                      URL  \
# 0      https://www.merriam-webster.com/dictionary/aut...
# 1               https://nl.wikipedia.org/wiki/Automotive
# 2           https://www.dictionary.com/browse/automotive
# 3      https://en.wikipedia.org/wiki/Automotive_industry
# 4      https://automotive-online.nl/management/laatst...
# ...                                                  ...
# 11963     https://www.britannica.com/place/New-York-City
# 11964                    https://www.citytv.com/toronto/
# 11965  https://www.theguardian.com/football/mancheste...
# 11966               https://www.hbo.com/sex-and-the-city
# 11967  https://www.thesun.co.uk/sport/football/team/1...
#
#                                                    Title  \
# 0             Automotive | Definition of Automotive by …
# 1                                 Automotive - Wikipedia
# 2             Automotive | Definition of Automotive at …
# 3                        Automotive industry - Wikipedia
# 4               Alle nieuwsrubrieken - Automotive Online
# ...                                                  ...
# 11963  New York City | Layout, People, Economy, Cultu...
# 11964                                            City TV
# 11965          Manchester City | Football | The Guardian
# 11966  Sex and the City - Official Website for the HB...
# 11967  Man City Latest News, Transfers & Fixtures - T...
#
#                                                  Snippet              Tier 1  \
# 0      Automotive definition is - self-propelled. How...          Automotive
# 1      Dit is een doorverwijspagina, bedoeld om de ve...          Automotive
# 2      Automotive definition, pertaining to the desig...          Automotive
# 3      The automotive industry comprises a wide range...          Automotive
# 4      Het platform voor het midden en hoger manageme...          Automotive
# ...                                                  ...                 ...
# 11963  New York City, officially the City of New York...  Content Source Geo
# 11964  Watch full episodes for free and see the TV sc...  Content Source Geo
# 11965  Manchester City hit a record 15-game winning s...  Content Source Geo
# 11966  The official website for Sex and the City on H...  Content Source Geo
# 11967  Manchester City are an English football team, ...  Content Source Geo
#
#       Tier 2 Tier 3 Tier 4                                           with_bs4  \
# 0          -      -      -                              Automotive | Defin...
# 1          -      -      -      Automotive - Wikipedia                    ...
# 2          -      -      -       Automotive | Definition of Automotive at ...
# 3          -      -      -      Automotive industry - Wikipedia           ...
# 4          -      -      -                Alle nieuwsrubrieken - Automotiv...
# ...      ...    ...    ...                                                ...
# 11963   City      -      -                               New York City | L...
# 11964   City      -      -  City TV You need to enable JavaScript to run t...
# 11965   City      -      -       Manchester City | Football | The Guardian...
# 11966   City      -      -  Sex and the City - Official Website for the HB...
# 11967   City      -      -             Man City Latest News Transfers & Fi...
#
#                                             with_justext  \
# 0        These example sentences are selected automat...
# 1                                                      -
# 2        General Motors warned that a global semicond...
# 3        The automotive industry began in the 1860s w...
# 4                                                      -
# ...                                                  ...
# 11963    Alternative Titles: New Amsterdam New Orange...
# 11964                                                  -
# 11965                                                  -
# 11966    Sarah Jessica Parker stars as Carrie Bradsha...
# 11967                                                  -
#
#                                           with_bs4_clean  \
# 0      automotive definition automotive merriamwebste...
# 1      automotive wikipedia automotive uit wikipedia ...
# 2      automotive definition automotive dictionarycom...
# 3      automotive industry wikipedia automotive indus...
# 4      alle nieuwsrubrieken automotive online automot...
# ...                                                  ...
# 11963  new york city layout people economy culture hi...
# 11964             city tv need enable javascript run app
# 11965  manchester city football guardian skip main co...
# 11966  sex city official website hbo serieslogoseries...
# 11967  man city late news transfer fixture sun jump d...
#
#                                       with_justext_clean
# 0      example sentence select automatically various ...
# 1                                                    NaN
# 2      general motor warn global semiconductor shorta...
# 3      automotive industry begin s hundred manufactur...
# 4                                                    NaN
# ...                                                  ...
# 11963  alternative title new amsterdam new orange new...
# 11964                                                NaN
# 11965                                                NaN
# 11966  sarah jessica parker star carrie bradshaw new ...
# 11967                                                NaN
#
# [11968 rows x 15 columns]

# %%
# iab_text.to_csv('../Data/IAB_text_v2.csv', index = False)

# %%
iab_text = pd.read_csv('../Data/IAB_text_v2.csv')

# %%
regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)

# %%
def remove_emojis(text):
    try:
        return regex_pattern.sub(r'',text)
    except:
        return np.nan

# %%
iab_text['with_bs4_clean'] = iab_text.apply(lambda x: remove_emojis(x['with_bs4_clean']), axis = 1)

# %%
iab_text['with_justext_clean'] = iab_text.apply(lambda x: remove_emojis(x['with_justext_clean']), axis = 1)

# %%
for i in range(len(iab_text)):
    try:
        text = iab_text.iloc[i].with_bs4
        lang = langdetect.detect(text)
        if lang != 'en':
            iab_text.loc[i, 'with_bs4_clean'] = np.nan
    except Exception as e:
        iab_text.loc[i, 'with_bs4_clean'] = np.nan

# %%
iab_text.dropna(subset = ['with_bs4_clean'])
# Out:
#       Unique ID Parent              Name  Position  \
# 0             1      -        Automotive         1
# 2             1      -        Automotive         3
# 3             1      -        Automotive         4
# 10            2      1  Auto Body Styles         1
# 11            2      1  Auto Body Styles         2
# ...         ...    ...               ...       ...
# 11963      1480   1219              City         6
# 11964      1480   1219              City         7
# 11965      1480   1219              City         8
# 11966      1480   1219              City         9
# 11967      1480   1219              City        10
#
#                                                      URL  \
# 0      https://www.merriam-webster.com/dictionary/aut...
# 2           https://www.dictionary.com/browse/automotive
# 3      https://en.wikipedia.org/wiki/Automotive_industry
# 10                   https://www.motor1.com/body-styles/
# 11     https://www.liveabout.com/pickup-trucks-body-s...
# ...                                                  ...
# 11963     https://www.britannica.com/place/New-York-City
# 11964                    https://www.citytv.com/toronto/
# 11965  https://www.theguardian.com/football/mancheste...
# 11966               https://www.hbo.com/sex-and-the-city
# 11967  https://www.thesun.co.uk/sport/football/team/1...
#
#                                                    Title  \
# 0             Automotive | Definition of Automotive by …
# 2             Automotive | Definition of Automotive at …
# 3                        Automotive industry - Wikipedia
# 10                        Body Styles Guide | Motor1.com
# 11           Pickup Trucks - Truck Body Styles Explained
# ...                                                  ...
# 11963  New York City | Layout, People, Economy, Cultu...
# 11964                                            City TV
# 11965          Manchester City | Football | The Guardian
# 11966  Sex and the City - Official Website for the HB...
# 11967  Man City Latest News, Transfers & Fixtures - T...
#
#                                                  Snippet              Tier 1  \
# 0      Automotive definition is - self-propelled. How...          Automotive
# 2      Automotive definition, pertaining to the desig...          Automotive
# 3      The automotive industry comprises a wide range...          Automotive
# 10     Find news, reviews and cars for sale broken do...          Automotive
# 11      · Most auto manufacturers call their traditio...          Automotive
# ...                                                  ...                 ...
# 11963  New York City, officially the City of New York...  Content Source Geo
# 11964  Watch full episodes for free and see the TV sc...  Content Source Geo
# 11965  Manchester City hit a record 15-game winning s...  Content Source Geo
# 11966  The official website for Sex and the City on H...  Content Source Geo
# 11967  Manchester City are an English football team, ...  Content Source Geo
#
#                  Tier 2 Tier 3 Tier 4  \
# 0                     -      -      -
# 2                     -      -      -
# 3                     -      -      -
# 10     Auto Body Styles      -      -
# 11     Auto Body Styles      -      -
# ...                 ...    ...    ...
# 11963              City      -      -
# 11964              City      -      -
# 11965              City      -      -
# 11966              City      -      -
# 11967              City      -      -
#
#                                                 with_bs4  \
# 0                                  Automotive | Defin...
# 2           Automotive | Definition of Automotive at ...
# 3          Automotive industry - Wikipedia           ...
# 10        Body Styles Guide | Motor1.com             ...
# 11                     Pickup Trucks - Truck Body Sty...
# ...                                                  ...
# 11963                               New York City | L...
# 11964  City TV You need to enable JavaScript to run t...
# 11965       Manchester City | Football | The Guardian...
# 11966  Sex and the City - Official Website for the HB...
# 11967             Man City Latest News Transfers & Fi...
#
#                                             with_justext  \
# 0        These example sentences are selected automat...
# 2        General Motors warned that a global semicond...
# 3        The automotive industry began in the 1860s w...
# 10                                                     -
# 11                                                     -
# ...                                                  ...
# 11963    Alternative Titles: New Amsterdam New Orange...
# 11964                                                  -
# 11965                                                  -
# 11966    Sarah Jessica Parker stars as Carrie Bradsha...
# 11967                                                  -
#
#                                           with_bs4_clean  \
# 0      automotive definition automotive merriamwebste...
# 2      automotive definition automotive dictionarycom...
# 3      automotive industry wikipedia automotive indus...
# 10     body style guide motorcom news review feature ...
# 11     pickup truck truck body style explain menu hom...
# ...                                                  ...
# 11963  new york city layout people economy culture hi...
# 11964             city tv need enable javascript run app
# 11965  manchester city football guardian skip main co...
# 11966  sex city official website hbo serieslogoseries...
# 11967  man city late news transfer fixture sun jump d...
#
#                                       with_justext_clean
# 0      example sentence select automatically various ...
# 2      general motor warn global semiconductor shorta...
# 3      automotive industry begin s hundred manufactur...
# 10                                                   NaN
# 11                                                   NaN
# ...                                                  ...
# 11963  alternative title new amsterdam new orange new...
# 11964                                                NaN
# 11965                                                NaN
# 11966  sarah jessica parker star carrie bradshaw new ...
# 11967                                                NaN
#
# [11380 rows x 15 columns]

# %%
for i in range(len(iab_text)):
    try:
        text = iab_text.iloc[i].with_justext
        lang = langdetect.detect(text)
        if lang != 'en':
            iab_text.loc[i, 'with_justext_clean'] = np.nan
    except Exception as e:
        iab_text.loc[i, 'with_justext_clean'] = np.nan

# %%
iab_text.dropna(subset = ['with_justext_clean'])
# Out:
#       Unique ID Parent              Name  Position  \
# 0             1      -        Automotive         1
# 2             1      -        Automotive         3
# 3             1      -        Automotive         4
# 12            2      1  Auto Body Styles         3
# 15            2      1  Auto Body Styles         6
# ...         ...    ...               ...       ...
# 11958      1480   1219              City         1
# 11959      1480   1219              City         2
# 11961      1480   1219              City         4
# 11963      1480   1219              City         6
# 11966      1480   1219              City         9
#
#                                                      URL  \
# 0      https://www.merriam-webster.com/dictionary/aut...
# 2           https://www.dictionary.com/browse/automotive
# 3      https://en.wikipedia.org/wiki/Automotive_industry
# 12     https://www.autoevolution.com/news/2021-dacia-...
# 15             https://autopartsfair.com/exterior_parts/
# ...                                                  ...
# 11958             https://www.dictionary.com/browse/city
# 11959          https://indianexpress.com/section/cities/
# 11961                http://smartcitydehradun.uk.gov.in/
# 11963     https://www.britannica.com/place/New-York-City
# 11966               https://www.hbo.com/sex-and-the-city
#
#                                                    Title  \
# 0             Automotive | Definition of Automotive by …
# 2             Automotive | Definition of Automotive at …
# 3                        Automotive industry - Wikipedia
# 12     2021 Dacia Logan Reimagined With Coupe, Pickup, …
# 15     Auto Body Parts Store - Exterior Body Parts for …
# ...                                                  ...
# 11958        City | Definition of City at Dictionary.com
# 11959  City News, Indian City Headlines, Latest City ...
# 11961                                SmartCity, Dehradun
# 11963  New York City | Layout, People, Economy, Cultu...
# 11966  Sex and the City - Official Website for the HB...
#
#                                                  Snippet              Tier 1  \
# 0      Automotive definition is - self-propelled. How...          Automotive
# 2      Automotive definition, pertaining to the desig...          Automotive
# 3      The automotive industry comprises a wide range...          Automotive
# 12     As for the Maximum Capacity Vehicle, cargo vol...          Automotive
# 15     Choose, compare & buy from a wide range of aut...          Automotive
# ...                                                  ...                 ...
# 11958  A city is a place where a large number of peop...  Content Source Geo
# 11959  Ahead of V-Day, city cops asked to increase pa...  Content Source Geo
# 11961  GoI under Smart City Mission Phase-4 100 citie...  Content Source Geo
# 11963  New York City, officially the City of New York...  Content Source Geo
# 11966  The official website for Sex and the City on H...  Content Source Geo
#
#                  Tier 2 Tier 3 Tier 4  \
# 0                     -      -      -
# 2                     -      -      -
# 3                     -      -      -
# 12     Auto Body Styles      -      -
# 15     Auto Body Styles      -      -
# ...                 ...    ...    ...
# 11958              City      -      -
# 11959              City      -      -
# 11961              City      -      -
# 11963              City      -      -
# 11966              City      -      -
#
#                                                 with_bs4  \
# 0                                  Automotive | Defin...
# 2           Automotive | Definition of Automotive at ...
# 3          Automotive industry - Wikipedia           ...
# 12           2021 Dacia Logan Reimagined With Coupe P...
# 15       Auto Body Parts Store - Exterior Body Parts ...
# ...                                                  ...
# 11958       City | Definition of City at Dictionary.c...
# 11959         City News Indian City Headlines Latest ...
# 11961     SmartCity Dehradun                         ...
# 11963                               New York City | L...
# 11966  Sex and the City - Official Website for the HB...
#
#                                             with_justext  \
# 0        These example sentences are selected automat...
# 2        General Motors warned that a global semicond...
# 3        The automotive industry began in the 1860s w...
# 12       2021 Dacia Logan Reimagined With Coupe Picku...
# 15       Discount Used Auto Parts Store  This website...
# ...                                                  ...
# 11958    VOCAB BUILDER  What is a basic definition of...
# 11959    Kachhadiya told The Indian Express “The moti...
# 11961    CLOCK TOWER - Dehradun  Clock tower also kno...
# 11963    Alternative Titles: New Amsterdam New Orange...
# 11966    Sarah Jessica Parker stars as Carrie Bradsha...
#
#                                           with_bs4_clean  \
# 0      automotive definition automotive merriamwebste...
# 2      automotive definition automotive dictionarycom...
# 3      automotive industry wikipedia automotive indus...
# 12     dacia logan reimagined coupe pickup mcv body s...
# 15     auto body part store exterior body part car tr...
# ...                                                  ...
# 11958  city definition city dictionarycom dictionaryc...
# 11959  city news indian city headline late city news ...
# 11961  smartcity dehradun dscl dscl board director or...
# 11963  new york city layout people economy culture hi...
# 11966  sex city official website hbo serieslogoseries...
#
#                                       with_justext_clean
# 0      example sentence select automatically various ...
# 2      general motor warn global semiconductor shorta...
# 3      automotive industry begin s hundred manufactur...
# 12     dacia logan reimagined coupe pickup mcv body s...
# 15     discount use auto part store website entry bes...
# ...                                                  ...
# 11958  vocab builder basic definition city city place...
# 11959  kachhadiya told indian express the motive behi...
# 11961  clock tower dehradun clock tower also know gha...
# 11963  alternative title new amsterdam new orange new...
# 11966  sarah jessica parker star carrie bradshaw new ...
#
# [8942 rows x 15 columns]

# %%
iab_text.to_csv("../Data/IAB_text_v3.csv", index = False)
