# %%
import pickle
import random
import pandas as pd
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import re
import ftfy
import humanize
from tabulate import tabulate

# %%
with open('../Data/articles.pkl', 'rb') as f:
    articles = pickle.load(f)
    
with open('../Data/all_muckrack_links.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
articles = articles[['author', 'site_name', 'title', 'description', 'full_text']]

# %%
iab_mod = pickle.load(open('../Data/IAB/IAB_classifier.p','rb'))
iab_vec = pickle.load(open('../Data/IAB/IAB_vectorizer.p','rb'))
iab_bin = pickle.load(open('../Data/IAB/IAB_binarizer.p','rb'))
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator MultiLabelBinarizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
nltk.download('stopwords')
nltk.download('wordnet')
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def iab_taxonomy_v2(text):
    text = clean(text)
    text = iab_vec.transform([text])
    res = iab_bin.inverse_transform(iab_mod.predict(text))
    return res

# %%
def clean(doc):
    doc = ftfy.fix_text(doc)
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    processed = re.sub(r"\d+","", normalized)
    y = processed.split()
    return ' '.join(y)

# %%
all_news = articles.merge(data, on = 'author')
all_news = all_news[all_news.Beat != '-'].reset_index()

# %%
random_news = random.sample(range(1, len(all_news)), 1000)
random_news = all_news[all_news.index.isin(random_news)].reset_index().drop(columns = ['level_0', 'index'])

# %%
random_news
# Out:
#                   author         site_name  \
# 0         David Matthews   nydailynews.com
# 1         David Matthews   nydailynews.com
# 2         David Matthews  sun-sentinel.com
# 3         David Matthews   nydailynews.com
# 4         Denis Slattery   nydailynews.com
# ..                   ...               ...
# 995       Sruthi Shankar              U.S.
# 996         Mary Kekatos       Mail Online
# 997  Jennifer A. Kingson             Axios
# 998         John Collett    Brisbane Times
# 999        Roya Backlund       StyleCaster
#
#                                                  title  \
# 0    U.S. teen who broke Cayman quarantine gets red...
# 1    70-year-old Taco Bell worker gets $6,000 gift ...
# 2    John Mulaney checks into rehab: reports - Sout...
# 3    Utah hiker survives 100 foot fall from cliff -...
# 4    Cuomo confident in Biden win, coronavirus aid ...
# ..                                                 ...
# 995  European stocks slide after virus fears knock ...
# 996  COVID-19 Texas: El Paso posts grim ad for temp...
# 997        The urban bathroom shortage worsens - Axios
# 998  Inner-city apartments face 10 per cent price s...
# 999  Libra December Horoscope 2020: A Time For Pers...
#
#                                            description  \
# 0    The Cayman Islands has reduced the prison sent...
# 1    A 70-year-old Taco Bell employee received more...
# 2    Comedian John Mulaney has checked into rehab b...
# 3    A Utah hiker survived after slipping and falli...
# 4    The governor, who backed the fellow Democrat’s...
# ..                                                 ...
# 995  European stocks fell on Thursday following sha...
# 996  The El Paso County Medical Examiner's Office p...
# 997  People are calling on municipal leaders to reo...
# 998  The recovery in property prices picked up spee...
# 999  Your Libra horoscope for December 2020 predict...
#
#                                              full_text  article_count  \
# 0     The Cayman Islands has reduced the prison sen...            113
# 1     70-year-old Taco Bell worker gets $6,000 gift...            113
# 2     Mulaney, 38, who joined the writing staff of ...            113
# 3     Utah hiker survives 100-foot fall from cliff ...            113
# 4     ALBANY — Gov. Cuomo isn’t surprised that Pres...             36
# ..                                                 ...            ...
# 995   European stocks slide after virus fears knock...             13
# 996   The El Paso County Medical Examiner's Office ...             10
# 997   The urban bathroom shortage worsens With libr...             11
# 998   Inner-city apartments face 10 per cent price ...             13
# 999   Libra, Your December Horoscope Predicts A TON...             26
#
#                              request_url                         redirect_url  \
# 0    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 1    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 2    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 3    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 4    https://muckrack.com/denis-slattery  https://muckrack.com/denis-slattery
# ..                                   ...                                  ...
# 995  https://muckrack.com/sruthi-shankar  https://muckrack.com/sruthi-shanker
# 996    https://muckrack.com/mary-kekatos     https://muckrack.com/marykekatos
# 997    https://muckrack.com/jenniferking    https://muckrack.com/jenniferking
# 998    https://muckrack.com/john-collett  https://muckrack.com/jcollett_money
# 999   https://muckrack.com/roya-backlund   https://muckrack.com/roya-backlund
#
#           method confidence                    Beat
# 0    brute force          -      Education, Science
# 1    brute force          -      Education, Science
# 2    brute force          -      Education, Science
# 3    brute force          -      Education, Science
# 4    brute force          -          Politics, U.S.
# ..           ...        ...                     ...
# 995  brute force          -    Business and Finance
# 996  brute force          -  Health, Metro New York
# 997     no match       0.62               Australia
# 998  brute force          -    Business and Finance
# 999  brute force          -  Arts and Entertainment
#
# [1000 rows x 11 columns]

# %%
random_news.author.value_counts()
# Out:
# James Rodger         6
# Rob Goldberg         4
# Alaa Elassar, CNN    4
# Rianne Addo          4
# David Matthews       4
#                     ..
# Eric McGowan         1
# Wendy Liberatore     1
# James Dutton         1
# Geoff Ziezulewicz    1
# Elana Lyn Gross      1
# Name: author, Length: 766, dtype: int64

# %%
random_news.Beat.value_counts()
# Out:
# United Kingdom                                            138
# Sports, United Kingdom                                     64
# Arts and Entertainment, United Kingdom                     47
# Arts and Entertainment                                     45
# Sports                                                     39
#                                                          ...
# Politics, Singapore                                         1
# Transportation, U.S.                                        1
# Arts and Entertainment, Food and Dining, U.S. Regional      1
# Arts and Entertainment, Metro Chicago, Sports, U.S.         1
# Military, U.S., U.S. Regional                               1
# Name: Beat, Length: 254, dtype: int64

# %%
test = []

# %%
for i in range(1000):
    news_article = random_news.iloc[i]
    content = news_article.full_text
    author_beat = news_article.Beat
    news_article = ' '.join([(news_article.title + ' ') * 4, (news_article.description + ' ') * 2, news_article.full_text])
    predicted_beat = iab_taxonomy_v2(news_article)
    test.append([author_beat, predicted_beat[0], content])

# %%
random_news
# Out:
#                   author         site_name  \
# 0         David Matthews   nydailynews.com
# 1         David Matthews   nydailynews.com
# 2         David Matthews  sun-sentinel.com
# 3         David Matthews   nydailynews.com
# 4         Denis Slattery   nydailynews.com
# ..                   ...               ...
# 995       Sruthi Shankar              U.S.
# 996         Mary Kekatos       Mail Online
# 997  Jennifer A. Kingson             Axios
# 998         John Collett    Brisbane Times
# 999        Roya Backlund       StyleCaster
#
#                                                  title  \
# 0    U.S. teen who broke Cayman quarantine gets red...
# 1    70-year-old Taco Bell worker gets $6,000 gift ...
# 2    John Mulaney checks into rehab: reports - Sout...
# 3    Utah hiker survives 100 foot fall from cliff -...
# 4    Cuomo confident in Biden win, coronavirus aid ...
# ..                                                 ...
# 995  European stocks slide after virus fears knock ...
# 996  COVID-19 Texas: El Paso posts grim ad for temp...
# 997        The urban bathroom shortage worsens - Axios
# 998  Inner-city apartments face 10 per cent price s...
# 999  Libra December Horoscope 2020: A Time For Pers...
#
#                                            description  \
# 0    The Cayman Islands has reduced the prison sent...
# 1    A 70-year-old Taco Bell employee received more...
# 2    Comedian John Mulaney has checked into rehab b...
# 3    A Utah hiker survived after slipping and falli...
# 4    The governor, who backed the fellow Democrat’s...
# ..                                                 ...
# 995  European stocks fell on Thursday following sha...
# 996  The El Paso County Medical Examiner's Office p...
# 997  People are calling on municipal leaders to reo...
# 998  The recovery in property prices picked up spee...
# 999  Your Libra horoscope for December 2020 predict...
#
#                                              full_text  article_count  \
# 0     The Cayman Islands has reduced the prison sen...            113
# 1     70-year-old Taco Bell worker gets $6,000 gift...            113
# 2     Mulaney, 38, who joined the writing staff of ...            113
# 3     Utah hiker survives 100-foot fall from cliff ...            113
# 4     ALBANY — Gov. Cuomo isn’t surprised that Pres...             36
# ..                                                 ...            ...
# 995   European stocks slide after virus fears knock...             13
# 996   The El Paso County Medical Examiner's Office ...             10
# 997   The urban bathroom shortage worsens With libr...             11
# 998   Inner-city apartments face 10 per cent price ...             13
# 999   Libra, Your December Horoscope Predicts A TON...             26
#
#                              request_url                         redirect_url  \
# 0    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 1    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 2    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 3    https://muckrack.com/david-matthews  https://muckrack.com/david-matthews
# 4    https://muckrack.com/denis-slattery  https://muckrack.com/denis-slattery
# ..                                   ...                                  ...
# 995  https://muckrack.com/sruthi-shankar  https://muckrack.com/sruthi-shanker
# 996    https://muckrack.com/mary-kekatos     https://muckrack.com/marykekatos
# 997    https://muckrack.com/jenniferking    https://muckrack.com/jenniferking
# 998    https://muckrack.com/john-collett  https://muckrack.com/jcollett_money
# 999   https://muckrack.com/roya-backlund   https://muckrack.com/roya-backlund
#
#           method confidence                    Beat
# 0    brute force          -      Education, Science
# 1    brute force          -      Education, Science
# 2    brute force          -      Education, Science
# 3    brute force          -      Education, Science
# 4    brute force          -          Politics, U.S.
# ..           ...        ...                     ...
# 995  brute force          -    Business and Finance
# 996  brute force          -  Health, Metro New York
# 997     no match       0.62               Australia
# 998  brute force          -    Business and Finance
# 999  brute force          -  Arts and Entertainment
#
# [1000 rows x 11 columns]

# %%
pd.read_html(tabulate(test, tablefmt='html', headers=["Muckrack beat", "Predicted tag", "Article content"]))[0].to_csv("test.csv")
