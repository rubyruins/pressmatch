# %%
import pandas as pd
import re
import pickle
import tfidf_matcher as tm
pd.options.mode.chained_assignment = None  # default='warn'
from urllib.request import Request, urlopen

# %%
with open('../Data/news.pkl', 'rb') as f:
    news = pickle.load(f)
    # 3844 unique authors

muckrack = pd.read_csv('../Data/muckrack_persons_fetchlist.csv')

# %%
def form_urls():
    temp = news[['author', 'article_count']].groupby('author').count().sort_values(['article_count'], ascending = False)
    temp = temp.reset_index()
    urls = []
    for i in range(len(temp)):
        url = temp.loc[i].author.lower()
        url = re.sub(r'\|.*$', '', url) # remove everything after |
        url = re.sub(r'\,.*$', '', url) # remove evrything after ,
        
        punctuations = '''!()[]{};:'"\,<>./?#$%^&*_~'''
        for x in url.lower(): 
            if x in punctuations: url = url.replace(x, "") # remove punctuations except hyphen
        url = re.sub(r'(\d+)', '', url) # remove numbers
        url = re.sub(r'(--)', '', url)
        url = re.sub(r'(\w+@\w+)', '', url) # remove emails
        url = ' '.join([i.strip() for i in url.split()]) # remove spaces and lowercase
        url = re.sub(r'(\s+)(and)(\s+)(\w*)(\s*)(\w*)', '', url) # remove anything after and
        keywords = ['sa', 'tulsa', 'editor', 'writer', 'world-herald', 'news', 'world', 'richmond', 'times-dispatch', 'new',
                   'hampshire', 'union', 'leader', 'for', 'the', 'state', 'journal', 'correspondant', 'sfgate', 'special',
                   'from', 'the', 'gazette', 'times', 'staff', 'senior', 'dr', 'correspondent', 'by', 'editorial board',
                   'research', 'wire reports', 'security', 'real', 'estate', 'to', 'post', 'and', 'courier', 'policy',
                   'commercial', 'bureau', 'political', 'roanoke', 'college', 'football', 'editorial','democrat-gazette',
                   'arizona', 'daily', 'star', '--hamburg', 'column', 'lincoln', 'managing', 'backstage', 'with', 'sports',
                   'ii', 'iii', 'capitol', 'media', 'services']
        url = ' '.join([i for i in url.split() if i not in keywords]) # remove other keywords
        url = re.sub(r'(@)', '', url) # remove handles
        url = 'https://muckrack.com/' + url.replace(' ', '-').strip('-') # make URL
        urls.append(url)
    temp['request_url'] = urls
    temp['redirect_url'] = urls
    temp['method'] = 'none'
    temp['confidence'] = '-'
    return temp

# %%
data = form_urls()

# %%
data
# Out:
#                 author  article_count                            request_url  \
# 0            Neil Shaw            523         https://muckrack.com/neil-shaw
# 1         James Rodger            512      https://muckrack.com/james-rodger
# 2           Jack Davis            251        https://muckrack.com/jack-davis
# 3           Adam Wells            223        https://muckrack.com/adam-wells
# 4        Sophie McCoid            218     https://muckrack.com/sophie-mccoid
# ...                ...            ...                                    ...
# 3833   Levi Sumagaysay             10   https://muckrack.com/levi-sumagaysay
# 3834       Ben Ashford             10       https://muckrack.com/ben-ashford
# 3835       Craig Brown             10       https://muckrack.com/craig-brown
# 3836  Courtney Connley             10  https://muckrack.com/courtney-connley
# 3837   MATTHEW PERRONE             10   https://muckrack.com/matthew-perrone
#
#                                redirect_url method confidence
# 0            https://muckrack.com/neil-shaw   none          -
# 1         https://muckrack.com/james-rodger   none          -
# 2           https://muckrack.com/jack-davis   none          -
# 3           https://muckrack.com/adam-wells   none          -
# 4        https://muckrack.com/sophie-mccoid   none          -
# ...                                     ...    ...        ...
# 3833   https://muckrack.com/levi-sumagaysay   none          -
# 3834       https://muckrack.com/ben-ashford   none          -
# 3835       https://muckrack.com/craig-brown   none          -
# 3836  https://muckrack.com/courtney-connley   none          -
# 3837   https://muckrack.com/matthew-perrone   none          -
#
# [3838 rows x 6 columns]

# %%
lookup = list(muckrack.url)
k_matches = 1
ngram_length = 3
def match_with_tfdif(wrong_url):
    wrong_url = [wrong_url]
    results = tm.matcher(wrong_url, lookup, k_matches, ngram_length)
    match_confidence = results['Match Confidence'].iloc[0]
    right_url = results['Lookup 1'].iloc[0]
    return match_confidence, right_url

# %%
match_with_tfdif('https://muckrack.com/ryan-taylor')
# Out:
# (0.89, 'https://muckrack.com/ryan-taylor-3')

# %%
for j in range(len(data)):
    url = data.iloc[j].request_url
    try:
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        res = urlopen(req)
        sauce = res.read()
        data.loc[j, 'method'] = 'brute force'
        data.loc[j, 'redirect_url'] = res.url
        print(j, "found brute force", url)
    except:
        confidence, url = match_with_tfdif(url)
        try:
            req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
            res = urlopen(req)
            sauce = res.read()
            data.loc[j, 'method'] = 'tfidf match'
            data.loc[j, 'confidence'] = confidence
            data.loc[j, 'request_url'] = url
            data.loc[j, 'redirect_url'] = res.url
            print(j, "found tfidf", url)
        except:
            print(j, "found nothing", url)
            data.loc[j, 'method'] = 'no match'
            # google scraper
    print()
# Out:
# 0 found brute force https://muckrack.com/neil-shaw
#
# 1 found brute force https://muckrack.com/james-rodger
#
# 2 found brute force https://muckrack.com/jack-davis
#
# 3 found brute force https://muckrack.com/adam-wells
#
# 4 found brute force https://muckrack.com/sophie-mccoid
#
# 5 found brute force https://muckrack.com/jack-otway
#
# 6 found brute force https://muckrack.com/joseph-zucker
#
# 7 found brute force https://muckrack.com/simon-duke
#
# 8 found brute force https://muckrack.com/maren-estrada
#
# 9 found brute force https://muckrack.com/dave-johnson
#
# 10 found brute force https://muckrack.com/brett-gibbons
#
# 11 found brute force https://muckrack.com/jenna-ciccotelli
#
# 12 found brute force https://muckrack.com/kipp-jones
#
# 13 found brute force https://muckrack.com/rianne-addo
#
# 14 found brute force https://muckrack.com/scott-polacek
#
# 15 found brute force https://muckrack.com/clark-schultz
#
# 16 found brute force https://muckrack.com/lewis-winter
#
# 17 found brute force https://muckrack.com/tom-bull
#
# 18 found brute force https://muckrack.com/rob-quinn
#
# 19 found brute force https://muckrack.com/hannah-bleau
#
# 20 found brute force https://muckrack.com/annie-martin
#
# 21 found brute force https://muckrack.com/pam-key
#
# 22 found brute force https://muckrack.com/max-demara
#
# 23 found brute force https://muckrack.com/roxy-simons
#
# 24 found brute force https://muckrack.com/carl-surran
#
# 25 found brute force https://muckrack.com/daniel-smith
#
# 26 found brute force https://muckrack.com/jessica-sansome
#
# 27 found brute force https://muckrack.com/daniel-blackham
#
# 28 found brute force https://muckrack.com/steven-brown
#
# 29 found brute force https://muckrack.com/eve-buckland
#
# 30 found brute force https://muckrack.com/clifford-colby
#
# 31 found brute force https://muckrack.com/c-douglas-golden
#
# 32 found brute force https://muckrack.com/rob-goldberg
#
# 33 found tfidf https://muckrack.com/matthew-cooper-3
#
# 34 found brute force https://muckrack.com/chris-smith
#
# 35 found brute force https://muckrack.com/helen-kelly
#
# 36 found brute force https://muckrack.com/ciara-farmer
#
# 37 found brute force https://muckrack.com/blake-schuster
#
# 38 found brute force https://muckrack.com/paul-tassi
#
# 39 found brute force https://muckrack.com/laura-fox
#
# 40 found brute force https://muckrack.com/marta-jary
#
# 41 found brute force https://muckrack.com/charlotte-dean
#
# 42 found brute force https://muckrack.com/alex-butler
#
# 43 found brute force https://muckrack.com/svar-nanan-sen
#
# 44 found tfidf https://muckrack.com/seamus
#
# 45 found tfidf https://muckrack.com/alessandra-schade
#
# 46 found brute force https://muckrack.com/aurora-bosotti
#
# 47 found brute force https://muckrack.com/david-byrom
#
# 48 found brute force https://muckrack.com/stuart-ballard
#
# 49 found brute force https://muckrack.com/sarah-abraham
#
# 50 found tfidf https://muckrack.com/ryan-taylor-3
#
# 51 found brute force https://muckrack.com/tyler-conway
#
# 52 found brute force https://muckrack.com/ollie-salt
#
# 53 found brute force https://muckrack.com/sean-ogrady
#
# 54 found brute force https://muckrack.com/mike-chiari
#
# 55 found brute force https://muckrack.com/claire-anderson
#
# 56 found brute force https://muckrack.com/beth-mishler-elmore
#
# 57 found brute force https://muckrack.com/joseph-s-pete
#
# 58 found brute force https://muckrack.com/lee-ryder
#
# 59 found brute force https://muckrack.com/john-mcdougall
#
# 60 found brute force https://muckrack.com/sophie-harris
#
# 61 found brute force https://muckrack.com/emma-parker
#
# 62 found tfidf https://muckrack.com/liam-dowd
#
# 63 found brute force https://muckrack.com/naomi-adedokun
#
# 64 found brute force https://muckrack.com/brian-marks
#
# 65 found brute force https://muckrack.com/charles-wade-palmer
#
# 66 found brute force https://muckrack.com/brian-dick
#
# 67 found brute force https://muckrack.com/richard-cusack
#
# 68 found brute force https://muckrack.com/gareth-bicknell
#
# 69 found brute force https://muckrack.com/olivia-wheeler
#
# 70 found brute force https://muckrack.com/darren-wells
#
# 71 found brute force https://muckrack.com/dan-bloom
#
# 72 found brute force https://muckrack.com/tim-daniels
#
# 73 found brute force https://muckrack.com/niomi-harris
#
# 74 found brute force https://muckrack.com/jessica-schladebeck
#
# 75 found brute force https://muckrack.com/brian-mazique
#
# 76 found brute force https://muckrack.com/andrea-reiher
#
# 77 found brute force https://muckrack.com/rebekah-evans
#
# 78 found brute force https://muckrack.com/joel-b-pollak
#
# 79 found brute force https://muckrack.com/ben-husband
#
# 80 found brute force https://muckrack.com/connie-rusk
#
# 81 found brute force https://muckrack.com/linda-howard
#
# 82 found tfidf https://muckrack.com/jessica-domel
#
# 83 found brute force https://muckrack.com/rebecca-miller
#
# 84 found tfidf https://muckrack.com/unzela-anna-khan-1
#
# 85 found brute force https://muckrack.com/shane-ireland
#
# 86 found brute force https://muckrack.com/evann-gastaldo
#
# 87 found brute force https://muckrack.com/dylan-donnelly
#
# 88 found brute force https://muckrack.com/charlie-malam
#
# 89 found brute force https://muckrack.com/cathy-owen
#
# 90 found brute force https://muckrack.com/ian-doyle
#
# 91 found brute force https://muckrack.com/ian-hanchett
#
# 92 found brute force https://muckrack.com/david-matthews
#
# 93 found brute force https://muckrack.com/natasha-hooper
#
# 94 found brute force https://muckrack.com/dominic-booth
#
# 95 found brute force https://muckrack.com/jr-de-groote
#
# 96 found brute force https://muckrack.com/valerie-edwards
#
# 97 found brute force https://muckrack.com/joseph-chapman
#
# 98 found brute force https://muckrack.com/deirdre-simonds
#
# 99 found brute force https://muckrack.com/bob-cronin
#
# 100 found brute force https://muckrack.com/katie-sewell
#
# 101 found brute force https://muckrack.com/clyde-hughes
#
# 102 found brute force https://muckrack.com/alice-scarsi
#
# 103 found brute force https://muckrack.com/andy-wilson
#
# 104 found tfidf https://muckrack.com/ray-rico
#
# 105 found brute force https://muckrack.com/liz-kiesche
#
# 106 found brute force https://muckrack.com/timothy-rapp
#
# 107 found brute force https://muckrack.com/katie-palmer
#
# 108 found brute force https://muckrack.com/charlotte-mcintyre
#
# 109 found brute force https://muckrack.com/frederica-miller
#
# 110 found brute force https://muckrack.com/amber-peake
#
# 111 found brute force https://muckrack.com/jenny-desborough
#
# 112 found brute force https://muckrack.com/ciaran-mcgrath
#
# 113 found brute force https://muckrack.com/rachel-pugh
#
# 114 found brute force https://muckrack.com/hayley-anderson
#
# 115 found brute force https://muckrack.com/ryan-smith
#
# 116 found brute force https://muckrack.com/glenn-garner
#
# 117 found brute force https://muckrack.com/austin-boyd
#
# 118 found brute force https://muckrack.com/emily-ferguson
#
# 119 found brute force https://muckrack.com/emma-munbodh
#
# 120 found brute force https://muckrack.com/lottie-gibbons
#
# 121 found brute force https://muckrack.com/laura-ocallaghan
#
# 122 found brute force https://muckrack.com/luke-chillingsworth
#
# 123 found brute force https://muckrack.com/mike-greger
#
# 124 found brute force https://muckrack.com/stephanie-dube-dwilson
#
# 125 found brute force https://muckrack.com/edward-browne
#
# 126 found brute force https://muckrack.com/jeff-poor
#
# 127 found brute force https://muckrack.com/alisha-buaya
#
# 128 found brute force https://muckrack.com/kaisha-langton
#
# 129 found brute force https://muckrack.com/andrea-tonks
#
# 130 found brute force https://muckrack.com/freddie-keighley
#
# 131 found brute force https://muckrack.com/theresa-braine
#
# 132 found tfidf https://muckrack.com/bryony-jones
#
# 133 found brute force https://muckrack.com/chris-beesley
#
# 134 found brute force https://muckrack.com/andrew-bullock
#
# 135 found tfidf https://muckrack.com/molly-patt
#
# 136 found brute force https://muckrack.com/kate-feldman
#
# 137 found brute force https://muckrack.com/adam-chapman
#
# 138 found brute force https://muckrack.com/carly-johnson
#
# 139 found brute force https://muckrack.com/jennifer-bisset
#
# 140 found brute force https://muckrack.com/beth-baumann
#
# 141 found brute force https://muckrack.com/nicole-douglas
#
# 142 found brute force https://muckrack.com/dion-dassanayake
#
# 143 found brute force https://muckrack.com/amy-furr
#
# 144 found brute force https://muckrack.com/daisy-maldonado
#
# 145 found brute force https://muckrack.com/aimee-robinson
# 146 found brute force https://muckrack.com/will-twigger
#
# 147 found brute force https://muckrack.com/jack-wright
#
# 148 found brute force https://muckrack.com/joe-tansey
#
# 149 found brute force https://muckrack.com/daniel-murphy
#
# 150 found brute force https://muckrack.com/joe-bray
#
# 151 found brute force https://muckrack.com/sophie-bateman
#
# 152 found brute force https://muckrack.com/chris-kitching
#
# 153 found brute force https://muckrack.com/joshua-smith
#
# 154 found brute force https://muckrack.com/jenn-gidman
#
# 155 found brute force https://muckrack.com/michelle-marshall
#
# 156 found brute force https://muckrack.com/rebecca-davison
#
# 157 found brute force https://muckrack.com/verity-sulway
#
# 158 found brute force https://muckrack.com/kristopher-knox
#
# 159 found brute force https://muckrack.com/ben-hooper
#
# 160 found brute force https://muckrack.com/rachel-russell
#
# 161 found brute force https://muckrack.com/holly-fleet
#
# 162 found brute force https://muckrack.com/paul-kasabian
#
# 163 found brute force https://muckrack.com/sam-elliott
#
# 164 found brute force https://muckrack.com/ryan-merrifield
#
# 165 found brute force https://muckrack.com/david-snelling
#
# 166 found brute force https://muckrack.com/adam-shergold
#
# 167 found brute force https://muckrack.com/mark-taylor
#
# 168 found brute force https://muckrack.com/rhys-daly
#
# 169 found brute force https://muckrack.com/mike-wehner
#
# 170 found brute force https://muckrack.com/gary-jones
#
# 171 found brute force https://muckrack.com/myriam-toua
#
# 172 found brute force https://muckrack.com/ashley-preece
#
# 173 found brute force https://muckrack.com/sophie-foster
#
# 174 found brute force https://muckrack.com/arden-dier
#
# 175 found brute force https://muckrack.com/katherine-rodriguez
#
# 176 found brute force https://muckrack.com/victoria-jones
#
# 177 found brute force https://muckrack.com/mikey-smith
#
# 178 found brute force https://muckrack.com/luke-matthews
#
# 179 found brute force https://muckrack.com/chris-watson
#
# 180 found brute force https://muckrack.com/peter-white
#
# 181 found brute force https://muckrack.com/samuel-luckhurst
#
# 182 found brute force https://muckrack.com/fay-watson
#
# 183 found brute force https://muckrack.com/chris-tomlinson
#
# 184 found brute force https://muckrack.com/jami-ganz
#
# 185 found brute force https://muckrack.com/michael-moran
#
# 186 found brute force https://muckrack.com/bruce-haring
#
# 187 found brute force https://muckrack.com/charlie-milward
#
# 188 found brute force https://muckrack.com/cassie-carpenter
#
# 189 found brute force https://muckrack.com/nika-shakhnazarova
#
# 190 found brute force https://muckrack.com/alan-friedman
#
# 191 found brute force https://muckrack.com/lucas-hill-paul
#
# 192 found brute force https://muckrack.com/harriet-mallinson
#
# 193 found brute force https://muckrack.com/shivali-best
#
# 194 found brute force https://muckrack.com/georgia-simcox
#
# 195 found brute force https://muckrack.com/tracy-wright
#
# 196 found brute force https://muckrack.com/charlotte-manning
#
# 197 found brute force https://muckrack.com/tyrone-marshall
#
# 198 found brute force https://muckrack.com/chloe-morgan
#
# 199 found brute force https://muckrack.com/sarah-vesty
#
# 200 found brute force https://muckrack.com/nellie-andreeva
#
# 201 found brute force https://muckrack.com/jessica-knibbs
#
# 202 found brute force https://muckrack.com/lauren-fruen
#
# 203 found brute force https://muckrack.com/marcus-banks
#
# 204 found brute force https://muckrack.com/sam-blitz
#
# 205 found brute force https://muckrack.com/brian-gallagher
#
# 206 found brute force https://muckrack.com/luke-may
#
# 207 found brute force https://muckrack.com/kelby-vera
#
# 208 found brute force https://muckrack.com/simon-bajkowski
#
# 209 found brute force https://muckrack.com/james-andrews
#
# 210 found brute force https://muckrack.com/louise-starkey
#
# 211 found brute force https://muckrack.com/nelson-oliveira
#
# 212 found brute force https://muckrack.com/james-brinsford
#
# 213 found brute force https://muckrack.com/ellen-kirwin
#
# 214 found brute force https://muckrack.com/storm-gifford
#
# 215 found brute force https://muckrack.com/sara-aisha-kent
#
# 216 found brute force https://muckrack.com/izzie-deibe
#
# 217 found brute force https://muckrack.com/melanie-kaidan
#
# 218 found brute force https://muckrack.com/mark-jones
#
# 219 found tfidf https://muckrack.com/charliespiering
#
# 220 found brute force https://muckrack.com/kate-dennett
#
# 221 found brute force https://muckrack.com/kate-nicholson
#
# 222 found brute force https://muckrack.com/niloofer-shaikh
#
# 223 found brute force https://muckrack.com/joshua-peck
#
# 224 found brute force https://muckrack.com/kirsty-mccormack
#
# 225 found brute force https://muckrack.com/bill-mcloughlin
#
# 226 found brute force https://muckrack.com/jemma-carr
#
# 227 found brute force https://muckrack.com/gabrielle-reyes
#
# 228 found brute force https://muckrack.com/charlie-bradley
#
# 229 found brute force https://muckrack.com/simon-osborne
#
# 230 found brute force https://muckrack.com/joe-barnes
#
# 231 found brute force https://muckrack.com/millie-bull
#
# 232 found brute force https://muckrack.com/tamara-davison
#
# 233 found brute force https://muckrack.com/oli-smith
#
# 234 found brute force https://muckrack.com/naman-ramachandran
#
# 235 found brute force https://muckrack.com/mikael-mckenzie
#
# 236 found brute force https://muckrack.com/heidi-parker
#
# 237 found brute force https://muckrack.com/sean-martin
#
# 238 found brute force https://muckrack.com/matt-atherton
#
# 239 found brute force https://muckrack.com/sean-szymkowski
#
# 240 found brute force https://muckrack.com/harriet-johnston
#
# 241 found brute force https://muckrack.com/joel-day
#
# 242 found brute force https://muckrack.com/brian-niemietz
#
# 243 found brute force https://muckrack.com/lorraine-king
#
# 244 found brute force https://muckrack.com/kishan-vaghela
#
# 245 found brute force https://muckrack.com/liam-thorp
#
# 246 found brute force https://muckrack.com/frances-mulraney
#
# 247 found brute force https://muckrack.com/sophie-law
#
# 248 found tfidf https://muckrack.com/ira-winkler
#
# 249 found brute force https://muckrack.com/connor-coombe-whitlock
#
# 250 found brute force https://muckrack.com/brian-mcgleenon
#
# 251 found brute force https://muckrack.com/mary-mrad
#
# 252 found brute force https://muckrack.com/joanna-crawley
#
# 253 found brute force https://muckrack.com/sebastian-kettley
#
# 254 found brute force https://muckrack.com/robin-cottle
#
# 255 found brute force https://muckrack.com/james-tapsfield
#
# 256 found brute force https://muckrack.com/gerrard-kaonga
#
# 257 found brute force https://muckrack.com/joseph-wilkinson
#
# 258 found brute force https://muckrack.com/lee-grimsditch
#
# 259 found brute force https://muckrack.com/sam-joseph-semon
#
# 260 found brute force https://muckrack.com/jason-zasky
#
# 261 found brute force https://muckrack.com/dave-burke
#
# 262 found brute force https://muckrack.com/cindy-tran
#
# 263 found brute force https://muckrack.com/callum-hoare
#
# 264 found tfidf https://muckrack.com/muri
#
# 265 found brute force https://muckrack.com/paul-gorst
#
# 266 found brute force https://muckrack.com/katie-fitzpatrick
#
# 267 found brute force https://muckrack.com/james-gordon
#
# 268 found brute force https://muckrack.com/matt-elliott
#
# 269 found brute force https://muckrack.com/tom-fish
#
# 270 found brute force https://muckrack.com/tom-grater
#
# 271 found brute force https://muckrack.com/kylie-stevens
#
# 272 found brute force https://muckrack.com/ellie-phillips
#
# 273 found brute force https://muckrack.com/jason-aycock
#
# 274 found brute force https://muckrack.com/neal-colgrass
#
# 275 found brute force https://muckrack.com/richard-percival
#
# 276 found brute force https://muckrack.com/chris-harper
#
# 277 found brute force https://muckrack.com/george-simpson
#
# 278 found brute force https://muckrack.com/jenny-kirkham
#
# 279 found brute force https://muckrack.com/gill-clark
#
# 280 found brute force https://muckrack.com/alex-davies
#
# 281 found brute force https://muckrack.com/jack-maidment
#
# 282 found brute force https://muckrack.com/vicki-newman
#
# 283 found brute force https://muckrack.com/lucy-needham
#
# 284 found brute force https://muckrack.com/parker-gabriel
#
# 285 found brute force https://muckrack.com/dave-thier
#
# 286 found brute force https://muckrack.com/jake-rill
#
# 287 found brute force https://muckrack.com/alexandra-del-rosario
# 288 found brute force https://muckrack.com/emily-hodgkin
#
# 289 found brute force https://muckrack.com/joe-pinkstone
#
# 290 found brute force https://muckrack.com/jonathan-adams
#
# 291 found brute force https://muckrack.com/emer-scully
#
# 292 found brute force https://muckrack.com/erin-coates
#
# 293 found brute force https://muckrack.com/luke-kenton
#
# 294 found brute force https://muckrack.com/sophie-haslett
#
# 295 found brute force https://muckrack.com/josh-challies
#
# 296 found brute force https://muckrack.com/peter-sblendorio
#
# 297 found brute force https://muckrack.com/abbie-llewelyn
#
# 298 found brute force https://muckrack.com/tom-davidson
#
# 299 found brute force https://muckrack.com/kurt-zindulka
#
# 300 found brute force https://muckrack.com/geoff-earle
#
# 301 found brute force https://muckrack.com/monica-greep
#
# 302 found brute force https://muckrack.com/julie-delahaye
#
# 303 found tfidf https://muckrack.com/andy-medici
#
# 304 found brute force https://muckrack.com/jessica-mcbride
#
# 305 found brute force https://muckrack.com/martina-bet
#
# 306 found brute force https://muckrack.com/tom-towers
#
# 307 found tfidf https://muckrack.com/paul-willuck
#
# 308 found brute force https://muckrack.com/eli-becht
#
# 309 found brute force https://muckrack.com/rachel-sharp
#
# 310 found brute force https://muckrack.com/kevin-kayhart
#
# 311 found brute force https://muckrack.com/bob-price
#
# 312 found brute force https://muckrack.com/jemima-mcevoy
#
# 313 found brute force https://muckrack.com/jessica-williams
#
# 314 found brute force https://muckrack.com/uche-amako
#
# 315 found brute force https://muckrack.com/josh-weiss
#
# 316 found brute force https://muckrack.com/thomas-d-williams
#
# 317 found brute force https://muckrack.com/yoel-minkoff
#
# 318 found brute force https://muckrack.com/anish-mondal
#
# 319 found brute force https://muckrack.com/rick-broida
#
# 320 found brute force https://muckrack.com/harish-kotian
#
# 321 found brute force https://muckrack.com/rachael-bunyan
#
# 322 found tfidf https://muckrack.com/helen-catt
#
# 323 found brute force https://muckrack.com/manon-dark
#
# 324 found brute force https://muckrack.com/sean-mccormick
#
# 325 found brute force https://muckrack.com/lewis-knight
#
# 326 found brute force https://muckrack.com/chiara-fiorillo
#
# 327 found brute force https://muckrack.com/sarah-bradbury
#
# 328 found brute force https://muckrack.com/jess-sheldon
#
# 329 found brute force https://muckrack.com/alex-shipman
#
# 330 found brute force https://muckrack.com/zack-sharf
#
# 331 found brute force https://muckrack.com/elizabeth-shim
#
# 332 found brute force https://muckrack.com/jack-wetherill
#
# 333 found brute force https://muckrack.com/harriet-alexander
#
# 334 found brute force https://muckrack.com/alison-denisco-rayome
#
# 335 found brute force https://muckrack.com/mark-duell
#
# 336 found brute force https://muckrack.com/safid-deen
#
# 337 found brute force https://muckrack.com/t-e-narasimhan
#
# 338 found brute force https://muckrack.com/trent-baker
#
# 339 found brute force https://muckrack.com/jennifer-smith
#
# 340 found brute force https://muckrack.com/james-robinson
#
# 341 found brute force https://muckrack.com/aliss-higham
#
# 342 found brute force https://muckrack.com/brandy-betz
#
# 343 found brute force https://muckrack.com/matt-addison
#
# 344 found brute force https://muckrack.com/kieran-jackson
#
# 345 found brute force https://muckrack.com/beth-abbit
#
# 346 found brute force https://muckrack.com/berny-torre
#
# 347 found brute force https://muckrack.com/luke-gardener
#
# 348 found brute force https://muckrack.com/molli-mitchell
#
# 349 found brute force https://muckrack.com/zoe-burrell
#
# 350 found brute force https://muckrack.com/claire-toureille
#
# 351 found brute force https://muckrack.com/david-carnoy
#
# 352 found brute force https://muckrack.com/jess-flaherty
#
# 353 found tfidf https://muckrack.com/luke-tress
#
# 354 found brute force https://muckrack.com/snejana-farberov
#
# 355 found brute force https://muckrack.com/warner-todd-huston
#
# 356 found brute force https://muckrack.com/dino-ray-ramos
#
# 357 found brute force https://muckrack.com/joseph-wilkes
#
# 358 found brute force https://muckrack.com/beth-heyn
#
# 359 found brute force https://muckrack.com/milly-vincent
#
# 360 found brute force https://muckrack.com/steven-mair
#
# 361 found brute force https://muckrack.com/andrew-solender
#
# 362 found brute force https://muckrack.com/stacy-liberatore
#
# 363 found brute force https://muckrack.com/kelly-ann-mills
#
# 364 found brute force https://muckrack.com/ciaran-kelly
#
# 365 found brute force https://muckrack.com/lori-pilger
#
# 366 found brute force https://muckrack.com/ariel-zilber
#
# 367 found brute force https://muckrack.com/jason-pham
#
# 368 found brute force https://muckrack.com/adrian-diaconescu
#
# 369 found brute force https://muckrack.com/emily-goodin
#
# 370 found brute force https://muckrack.com/greg-macafee
#
# 371 found brute force https://muckrack.com/bobby-vincent
#
# 372 found brute force https://muckrack.com/sam-baker
#
# 373 found brute force https://muckrack.com/matt-vespa
#
# 374 found brute force https://muckrack.com/bronson-stocking
#
# 375 found brute force https://muckrack.com/pat-leonard
#
# 376 found brute force https://muckrack.com/alex-milne
#
# 377 found brute force https://muckrack.com/luke-andrews
#
# 378 found tfidf https://muckrack.com/ron-bliss
#
# 379 found brute force https://muckrack.com/alex-dicken
#
# 380 found brute force https://muckrack.com/wade-sheridan
#
# 381 found brute force https://muckrack.com/phil-kirkbride
#
# 382 found brute force https://muckrack.com/rebecca-day
#
# 383 found brute force https://muckrack.com/joseph-green
#
# 384 found brute force https://muckrack.com/jordan-coussins
#
# 385 found brute force https://muckrack.com/daniel-bird
#
# 386 found brute force https://muckrack.com/karen-butler
#
# 387 found brute force https://muckrack.com/sam-mckewon
#
# 388 found brute force https://muckrack.com/jessica-green
#
# 389 found brute force https://muckrack.com/jack-hardwick
#
# 390 found brute force https://muckrack.com/awr-hawkins
#
# 391 found brute force https://muckrack.com/kevin-foote
#
# 392 found brute force https://muckrack.com/katie-dickinson
#
# 393 found tfidf https://muckrack.com/jacobsiegal
#
# 394 found brute force https://muckrack.com/devanjana-nag
#
# 395 found brute force https://muckrack.com/joe-davies
#
# 396 found brute force https://muckrack.com/jonathan-chadwick
#
# 397 found brute force https://muckrack.com/antonia-paget
#
# 398 found brute force https://muckrack.com/nikki-schwab
#
# 399 found brute force https://muckrack.com/ian-mitchelmore
#
# 400 found brute force https://muckrack.com/laxmi-negi
#
# 401 found brute force https://muckrack.com/kathryn-ingate
#
# 402 found brute force https://muckrack.com/lizzy-buchan
#
# 403 found brute force https://muckrack.com/dan-heching
#
# 404 found brute force https://muckrack.com/hannah-graham
#
# 405 found brute force https://muckrack.com/aaron-brown
#
# 406 found brute force https://muckrack.com/richard-fay
#
# 407 found brute force https://muckrack.com/rose-hill
#
# 408 found brute force https://muckrack.com/candice-jackson
#
# 409 found brute force https://muckrack.com/denise-petski
#
# 410 found brute force https://muckrack.com/dylan-gwinn
#
# 411 found brute force https://muckrack.com/ailbhe-macmahon
#
# 412 found brute force https://muckrack.com/neela-debnath
#
# 413 found brute force https://muckrack.com/keith-griffith
#
# 414 found brute force https://muckrack.com/taylor-vollman
#
# 415 found brute force https://muckrack.com/andrew-court
#
# 416 found brute force https://muckrack.com/james-moncur
#
# 417 found tfidf https://muckrack.com/dave-mcnamara
#
# 418 found brute force https://muckrack.com/isabella-nikolic
#
# 419 found brute force https://muckrack.com/katelyn-caralle
#
# 420 found brute force https://muckrack.com/anthony-dalessandro
#
# 421 found brute force https://muckrack.com/katie-feehan
#
# 422 found brute force https://muckrack.com/nisha-mal
#
# 423 found brute force https://muckrack.com/ian-randall
#
# 424 found brute force https://muckrack.com/saffron-otter
#
# 425 found tfidf https://muckrack.com/torcuil
#
# 426 found brute force https://muckrack.com/sarra-gray
#
# 427 found brute force https://muckrack.com/katie-conner
#
# 428 found brute force https://muckrack.com/jeff-richgels
#
# 429 found brute force https://muckrack.com/chloe-lee-longhetti
#
# 430 found brute force https://muckrack.com/sonia-sharma
#
# 431 found brute force https://muckrack.com/kshitij-bhargava
# 432 found brute force https://muckrack.com/john-binder
#
# 433 found brute force https://muckrack.com/monique-friedlander
#
# 434 found brute force https://muckrack.com/dade-hayes
#
# 435 found brute force https://muckrack.com/matthew-dresch
#
# 436 found brute force https://muckrack.com/marlene-lenthang
#
# 437 found brute force https://muckrack.com/mary-kekatos
#
# 438 found brute force https://muckrack.com/thomas-bristow
#
# 439 found brute force https://muckrack.com/connor-oneill
#
# 440 found brute force https://muckrack.com/paige-holland
#
# 441 found brute force https://muckrack.com/adam-jones
#
# 442 found brute force https://muckrack.com/glen-williams
#
# 443 found brute force https://muckrack.com/catherine-murphy
#
# 444 found brute force https://muckrack.com/breitbart-london
#
# 445 found brute force https://muckrack.com/john-hayward
#
# 446 found brute force https://muckrack.com/kelly-ashmore
#
# 447 found brute force https://muckrack.com/warren-muggleton
#
# 448 found brute force https://muckrack.com/cortney-obrien
#
# 449 found tfidf https://muckrack.com/keith-pollard
#
# 450 found brute force https://muckrack.com/ryan-morrison
#
# 451 found brute force https://muckrack.com/kristy-johnson
#
# 452 found brute force https://muckrack.com/jason-chester
#
# 453 found brute force https://muckrack.com/ben-kew
#
# 454 found brute force https://muckrack.com/mamta-mayani
#
# 455 found brute force https://muckrack.com/newser-editors
#
# 456 found brute force https://muckrack.com/matty-hewitt
#
# 457 found brute force https://muckrack.com/callum-crumlish
#
# 458 found brute force https://muckrack.com/samantha-masters
#
# 459 found brute force https://muckrack.com/shive-prema
#
# 460 found brute force https://muckrack.com/harry-howard
#
# 461 found tfidf https://muckrack.com/vinny-steves
#
# 462 found brute force https://muckrack.com/christine-rendon
#
# 463 found brute force https://muckrack.com/rebecca-alter
#
# 464 found brute force https://muckrack.com/dave-goldiner
#
# 465 found tfidf https://muckrack.com/d-cruz
#
# 466 found brute force https://muckrack.com/leah-barkoukis
#
# 467 found brute force https://muckrack.com/jon-hebditch
#
# 468 found brute force https://muckrack.com/kathryn-batte
#
# 469 found brute force https://muckrack.com/archie-griggs
#
# 470 found brute force https://muckrack.com/chanel-georgina
#
# 471 found brute force https://muckrack.com/andy-philip
#
# 472 found brute force https://muckrack.com/john-fogarty
#
# 473 found brute force https://muckrack.com/sam-carroll
#
# 474 found brute force https://muckrack.com/tom-pyman
#
# 475 found brute force https://muckrack.com/hayley-richardson
#
# 476 found brute force https://muckrack.com/halle-kiefer
#
# 477 found brute force https://muckrack.com/ashlie-blakey
#
# 478 found brute force https://muckrack.com/alana-mazzoni
#
# 479 found brute force https://muckrack.com/alana-mastrangelo
#
# 480 found brute force https://muckrack.com/zara-whelan
#
# 481 found brute force https://muckrack.com/david-wilcock
#
# 482 found brute force https://muckrack.com/sophie-roberts
#
# 483 found brute force https://muckrack.com/ollie-lewis
#
# 484 found brute force https://muckrack.com/nick-horner
#
# 485 found brute force https://muckrack.com/isobel-hine
#
# 486 found brute force https://muckrack.com/lottie-oneill
#
# 487 found brute force https://muckrack.com/victoria-friedman
#
# 488 found brute force https://muckrack.com/simon-lewis
#
# 489 found brute force https://muckrack.com/kelsey-mccarson
#
# 490 found brute force https://muckrack.com/sindhu-kashyaap
#
# 491 found brute force https://muckrack.com/demeter-stamell
#
# 492 found brute force https://muckrack.com/tom-duffy
#
# 493 found brute force https://muckrack.com/zoe-forsey
#
# 494 found brute force https://muckrack.com/evan-bland
#
# 495 found brute force https://muckrack.com/charlie-mason
#
# 496 found brute force https://muckrack.com/emily-kirkpatrick
#
# 497 found brute force https://muckrack.com/milo-boyd
#
# 498 found tfidf https://muckrack.com/stephen-morris
#
# 499 found brute force https://muckrack.com/lucas-nolan
#
# 500 found brute force https://muckrack.com/alice-murphy
#
# 501 found brute force https://muckrack.com/karu-f-daniels
#
# 502 found brute force https://muckrack.com/khyathi-dalal
#
# 503 found brute force https://muckrack.com/emily-crane
#
# 504 found brute force https://muckrack.com/sean-keane
#
# 505 found brute force https://muckrack.com/todd-spangler
#
# 506 found brute force https://muckrack.com/brogan-leigh-hurst
#
# 507 found brute force https://muckrack.com/tom-ciccotta
#
# 508 found brute force https://muckrack.com/charlotte-hadfield
#
# 509 found brute force https://muckrack.com/callum-vurley
#
# 510 found brute force https://muckrack.com/alan-weston
#
# 511 found brute force https://muckrack.com/jackson-barron
#
# 512 found brute force https://muckrack.com/oli-gamp
#
# 513 found brute force https://muckrack.com/carly-stern
#
# 514 found brute force https://muckrack.com/kelly-smith
#
# 515 found brute force https://muckrack.com/ben-glaze
#
# 516 found brute force https://muckrack.com/daniel-oyefusi
#
# 517 found brute force https://muckrack.com/jonathan-mcfarlane
#
# 518 found brute force https://muckrack.com/frances-kindon
#
# 519 found brute force https://muckrack.com/amelia-wynne
#
# 520 found brute force https://muckrack.com/jack-brewster
#
# 521 found brute force https://muckrack.com/oliver-milne
#
# 522 found brute force https://muckrack.com/catalin-cimpanu
#
# 523 found brute force https://muckrack.com/james-hunter
#
# 524 found brute force https://muckrack.com/kathryn-williams
#
# 525 found brute force https://muckrack.com/jack-newman
#
# 526 found brute force https://muckrack.com/tara-oneill
#
# 527 found brute force https://muckrack.com/andreas-wiseman
#
# 528 found brute force https://muckrack.com/rachel-mcgrath
#
# 529 found brute force https://muckrack.com/kieran-murray
#
# 530 found tfidf https://muckrack.com/christi-parsons
#
# 531 found brute force https://muckrack.com/avneet-kaur
#
# 532 found brute force https://muckrack.com/katie-pavlich
#
# 533 found brute force https://muckrack.com/john-johnson
#
# 534 found brute force https://muckrack.com/reagan-mccarthy
#
# 535 found brute force https://muckrack.com/jake-kanter
#
# 536 found brute force https://muckrack.com/julio-rosas
#
# 537 found brute force https://muckrack.com/claire-shaffer
#
# 538 found brute force https://muckrack.com/claire-gilbody-dickerson
#
# 539 found brute force https://muckrack.com/talia-shadwell
#
# 540 found brute force https://muckrack.com/david-furones
#
# 541 found brute force https://muckrack.com/andy-mcgilvray
#
# 542 found brute force https://muckrack.com/melisha-kaur
#
# 543 found tfidf https://muckrack.com/ryan-haney-1
#
# 544 found brute force https://muckrack.com/sarah-keoghan
#
# 545 found tfidf https://muckrack.com/chris-bassett
#
# 546 found brute force https://muckrack.com/mark-smith
#
# 547 found tfidf https://muckrack.com/danielkreps
#
# 548 found brute force https://muckrack.com/courtney-pochin
#
# 549 found brute force https://muckrack.com/patrick-frater
#
# 550 found brute force https://muckrack.com/surbhi-jain
#
# 551 found tfidf https://muckrack.com/paulhutcheon
#
# 552 found brute force https://muckrack.com/william-cole
#
# 553 found brute force https://muckrack.com/paul-thomson
#
# 554 found brute force https://muckrack.com/penny-starr
#
# 555 found brute force https://muckrack.com/elliott-jackson
#
# 556 found brute force https://muckrack.com/fionnula-hainey
#
# 557 found brute force https://muckrack.com/katie-weston
#
# 558 found brute force https://muckrack.com/tom-coleman
#
# 559 found brute force https://muckrack.com/jonathan-spencer
#
# 560 found brute force https://muckrack.com/erica-tempesta
#
# 561 found brute force https://muckrack.com/olivia-tobin
#
# 562 found brute force https://muckrack.com/tim-stickings
#
# 563 found brute force https://muckrack.com/jonas-shaffer
#
# 564 found brute force https://muckrack.com/raakhi-jagga
#
# 565 found brute force https://muckrack.com/amie-just
#
# 566 found brute force https://muckrack.com/faith-ridler
#
# 567 found brute force https://muckrack.com/grace-dean
#
# 568 found brute force https://muckrack.com/sophie-blackman
#
# 569 found brute force https://muckrack.com/john-cross
#
# 570 found brute force https://muckrack.com/charlotte-tutton
#
# 571 found brute force https://muckrack.com/sandeep-soni
#
# 572 found brute force https://muckrack.com/prabhjeet-bhatla
#
# 573 found brute force https://muckrack.com/sana-farzeen
#
# 574 found brute force https://muckrack.com/nancy-dillon
# 575 found brute force https://muckrack.com/jack-montgomery
#
# 576 found brute force https://muckrack.com/david-ng
#
# 577 found brute force https://muckrack.com/ross-ibbetson
#
# 578 found brute force https://muckrack.com/jem-aswad
#
# 579 found brute force https://muckrack.com/daniel-morrow
#
# 580 found brute force https://muckrack.com/dan-carden
#
# 581 found brute force https://muckrack.com/jane-herz
#
# 582 found brute force https://muckrack.com/emily-scrivener
#
# 583 found brute force https://muckrack.com/stephen-johnson
#
# 584 found brute force https://muckrack.com/tita-smith
#
# 585 found brute force https://muckrack.com/frances-martel
#
# 586 found brute force https://muckrack.com/ted-johnson
#
# 587 found brute force https://muckrack.com/bridie-pearson-jones
#
# 588 found brute force https://muckrack.com/brooks-hays
#
# 589 found brute force https://muckrack.com/vandana-singh
#
# 590 found brute force https://muckrack.com/katie-harris
#
# 591 found brute force https://muckrack.com/edgar-thompson
#
# 592 found brute force https://muckrack.com/kevin-stankiewicz
#
# 593 found brute force https://muckrack.com/barbara-hodgson
#
# 594 found brute force https://muckrack.com/eoghan-cormican
#
# 595 found brute force https://muckrack.com/lydia-stephens
#
# 596 found tfidf https://muckrack.com/charliecook
#
# 597 found brute force https://muckrack.com/lisa-hodge
#
# 598 found brute force https://muckrack.com/liam-martin
#
# 599 found brute force https://muckrack.com/dan-laurie
#
# 600 found brute force https://muckrack.com/james-bickerton
#
# 601 found brute force https://muckrack.com/matt-olberding
#
# 602 found brute force https://muckrack.com/james-caven
#
# 603 found brute force https://muckrack.com/david-bentley
#
# 604 found brute force https://muckrack.com/chris-jewers
#
# 605 found brute force https://muckrack.com/gael-fashingbauer-cooper
#
# 606 found brute force https://muckrack.com/david-priest
#
# 607 found brute force https://muckrack.com/caroline-warnock
#
# 608 found brute force https://muckrack.com/jonathan-walker
#
# 609 found brute force https://muckrack.com/charlie-moore
#
# 610 found brute force https://muckrack.com/seamus-mcdonnell
#
# 611 found brute force https://muckrack.com/simon-kent
#
# 612 found brute force https://muckrack.com/nathan-bliss
#
# 613 found brute force https://muckrack.com/shaffiq-alkhatib
#
# 614 found brute force https://muckrack.com/ben-winck
#
# 615 found brute force https://muckrack.com/michael-a-gayed
#
# 616 found brute force https://muckrack.com/michael-lev
#
# 617 found brute force https://muckrack.com/ian-johnson
#
# 618 found brute force https://muckrack.com/charlotte-mitchell
#
# 619 found tfidf https://muckrack.com/amy-green
#
# 620 found brute force https://muckrack.com/will-thorne
#
# 621 found brute force https://muckrack.com/nathan-salt
#
# 622 found brute force https://muckrack.com/mark-pirie
#
# 623 found tfidf https://muckrack.com/marciecipriani
#
# 624 found brute force https://muckrack.com/chris-mccall
#
# 625 found brute force https://muckrack.com/chris-sommerfeldt
#
# 626 found brute force https://muckrack.com/shant-shahrigian
#
# 627 found brute force https://muckrack.com/steve-robson
#
# 628 found brute force https://muckrack.com/zack-kelberman
#
# 629 found brute force https://muckrack.com/clive-hammond
#
# 630 found brute force https://muckrack.com/louise-randell
#
# 631 found brute force https://muckrack.com/matthew-wright
#
# 632 found brute force https://muckrack.com/luke-hawker
#
# 633 found brute force https://muckrack.com/colten-bartholomew
#
# 634 found brute force https://muckrack.com/tim-balk
#
# 635 found brute force https://muckrack.com/elizabeth-roche
#
# 636 found brute force https://muckrack.com/eric-mack
#
# 637 found brute force https://muckrack.com/kelsey-wilkie
#
# 638 found tfidf https://muckrack.com/amanda-thompson
#
# 639 found brute force https://muckrack.com/liam-tung
#
# 640 found brute force https://muckrack.com/eli-blumenthal
#
# 641 found brute force https://muckrack.com/alison-durkee
#
# 642 found brute force https://muckrack.com/vickiie-oliphant
#
# 643 found brute force https://muckrack.com/karen-ruiz
#
# 644 found brute force https://muckrack.com/george-stoia
#
# 645 found brute force https://muckrack.com/bhvishya-patel
#
# 646 found brute force https://muckrack.com/jessica-snouwaert
#
# 647 found brute force https://muckrack.com/erik-kain
#
# 648 found tfidf https://muckrack.com/johana-suarez
#
# 649 found brute force https://muckrack.com/megan-sheets
#
# 650 found brute force https://muckrack.com/danny-gallagher
#
# 651 found brute force https://muckrack.com/clare-mccarthy
#
# 652 found brute force https://muckrack.com/kali-lindsay
#
# 653 found brute force https://muckrack.com/ang-qing
#
# 654 found brute force https://muckrack.com/john-nolte
#
# 655 found brute force https://muckrack.com/cameron-arcand
#
# 656 found brute force https://muckrack.com/sam-blanchard
#
# 657 found brute force https://muckrack.com/john-paul-clark
#
# 658 found brute force https://muckrack.com/daniel-holland
#
# 659 found brute force https://muckrack.com/carlie-porterfield
#
# 660 found brute force https://muckrack.com/rebecca-falconer
#
# 661 found brute force https://muckrack.com/joe-walsh
#
# 662 found brute force https://muckrack.com/marc-narducci
#
# 663 found brute force https://muckrack.com/ben-turner-le
#
# 664 found brute force https://muckrack.com/david-shepardson
#
# 665 found brute force https://muckrack.com/sophie-halle-richards
#
# 666 found tfidf https://muckrack.com/seanmurphy
#
# 667 found brute force https://muckrack.com/lauren-edmonds
#
# 668 found brute force https://muckrack.com/yoni-heisler
#
# 669 found brute force https://muckrack.com/neil-docking
#
# 670 found brute force https://muckrack.com/priscilla-aguirre
#
# 671 found brute force https://muckrack.com/stuart-gillespie
#
# 672 found brute force https://muckrack.com/taylor-dart
#
# 673 found brute force https://muckrack.com/caleb-taylor
#
# 674 found brute force https://muckrack.com/lucas-gonzalez
#
# 675 found brute force https://muckrack.com/theo-squires
#
# 676 found tfidf https://muckrack.com/omarkelly
#
# 677 found brute force https://muckrack.com/samrat-sharma
#
# 678 found brute force https://muckrack.com/taylor-pettaway
#
# 679 found brute force https://muckrack.com/christopher-dabe
#
# 680 found brute force https://muckrack.com/nicole-glennon
#
# 681 found brute force https://muckrack.com/liam-bryce
#
# 682 found brute force https://muckrack.com/josh-saunders
#
# 683 found tfidf https://muckrack.com/osmattmurschel
#
# 684 found brute force https://muckrack.com/luke-johnson
#
# 685 found brute force https://muckrack.com/chris-pleasance
#
# 686 found tfidf https://muckrack.com/joshua-carroll
#
# 687 found brute force https://muckrack.com/susan-knox
#
# 688 found brute force https://muckrack.com/ben-geman
#
# 689 found brute force https://muckrack.com/judith-tonner
#
# 690 found brute force https://muckrack.com/ben-james
#
# 691 found brute force https://muckrack.com/susan-berry
#
# 692 found tfidf https://muckrack.com/casey-tingle
#
# 693 found brute force https://muckrack.com/maria-vultaggio
#
# 694 found brute force https://muckrack.com/simon-thomas
#
# 695 found brute force https://muckrack.com/james-boyd
#
# 696 found brute force https://muckrack.com/joe-thomas
#
# 697 found brute force https://muckrack.com/dan-avery
#
# 698 found brute force https://muckrack.com/simon-meechan
#
# 699 found brute force https://muckrack.com/tiffany-lo
#
# 700 found brute force https://muckrack.com/kyle-osullivan
#
# 701 found brute force https://muckrack.com/amy-dickinson
#
# 702 found brute force https://muckrack.com/shalini-nagarajan
#
# 703 found brute force https://muckrack.com/james-gant
#
# 704 found brute force https://muckrack.com/rich-jones
#
# 705 found brute force https://muckrack.com/stefan-kyriazis
#
# 706 found brute force https://muckrack.com/charlotte-daly
#
# 707 found brute force https://muckrack.com/trevor-squire
#
# 708 found brute force https://muckrack.com/kristian-winfield
#
# 709 found brute force https://muckrack.com/jane-tyler
#
# 710 found brute force https://muckrack.com/lucy-domachowski
#
# 711 found brute force https://muckrack.com/chris-knight
#
# 712 found brute force https://muckrack.com/will-hayward
#
# 713 found brute force https://muckrack.com/anna-ortiz
#
# 714 found brute force https://muckrack.com/connor-boyd-assistant
#
# 715 found tfidf https://muckrack.com/pang-chieh-ho
#
# 716 found brute force https://muckrack.com/megan-nisbet
#
# 717 found brute force https://muckrack.com/christine-younan
# 718 found tfidf https://muckrack.com/aodhan-gregory
#
# 719 found brute force https://muckrack.com/helena-vesty
#
# 720 found brute force https://muckrack.com/danyal-hussain
#
# 721 found brute force https://muckrack.com/graeme-young
#
# 722 found brute force https://muckrack.com/robin-fambrough
#
# 723 found brute force https://muckrack.com/kirsty-feerick
#
# 724 found brute force https://muckrack.com/heather-waugh
#
# 725 found tfidf https://muckrack.com/amanda-c-kooser
#
# 726 found brute force https://muckrack.com/jane-lavender
#
# 727 found brute force https://muckrack.com/kathleen-speirs
#
# 728 found brute force https://muckrack.com/adam-s-levy
#
# 729 found tfidf https://muckrack.com/stephen-brown
#
# 730 found brute force https://muckrack.com/christy-wheeland
#
# 731 found brute force https://muckrack.com/matt-dennien
#
# 732 found brute force https://muckrack.com/katie-sands
#
# 733 found brute force https://muckrack.com/laura-clements
#
# 734 found brute force https://muckrack.com/sam-mcevoy
#
# 735 found brute force https://muckrack.com/alexander-brock
#
# 736 found brute force https://muckrack.com/justin-barney
#
# 737 found brute force https://muckrack.com/david-morton
#
# 738 found brute force https://muckrack.com/tommy-beer
#
# 739 found brute force https://muckrack.com/ali-daher
#
# 740 found brute force https://muckrack.com/stephanie-balloo
#
# 741 found brute force https://muckrack.com/sara-fischer
#
# 742 found brute force https://muckrack.com/kirsten-mcstay
#
# 743 found brute force https://muckrack.com/ellise-shafer
#
# 744 found brute force https://muckrack.com/dan-falvey
#
# 745 found brute force https://muckrack.com/shreya-nandi
#
# 746 found brute force https://muckrack.com/john-oconnor
#
# 747 found brute force https://muckrack.com/shannon-ryan
#
# 748 found brute force https://muckrack.com/sameer-suri
#
# 749 found brute force https://muckrack.com/bob-kasarda
#
# 750 found brute force https://muckrack.com/amie-wilson
#
# 751 found brute force https://muckrack.com/robert-rowlands
#
# 752 found brute force https://muckrack.com/emma-gill
#
# 753 found brute force https://muckrack.com/darren-boyle
#
# 754 found brute force https://muckrack.com/shawn-hein
#
# 755 found brute force https://muckrack.com/andy-shipley
#
# 756 found brute force https://muckrack.com/bulbul-dhawan
#
# 757 found brute force https://muckrack.com/mary-freda
#
# 758 found brute force https://muckrack.com/latoya-gayle
#
# 759 found brute force https://muckrack.com/ben-perrin
#
# 760 found brute force https://muckrack.com/charlie-osborne
#
# 761 found brute force https://muckrack.com/will-stewart
#
# 762 found brute force https://muckrack.com/lizzie-smith
#
# 763 found brute force https://muckrack.com/dan-sales
#
# 764 found brute force https://muckrack.com/eric-bailey
#
# 765 found brute force https://muckrack.com/mike-kelly
#
# 766 found brute force https://muckrack.com/emily-bicks
#
# 767 found brute force https://muckrack.com/katrina-turrill
#
# 768 found brute force https://muckrack.com/alex-richards
#
# 769 found brute force https://muckrack.com/robert-dalling
#
# 770 found brute force https://muckrack.com/neetu-chandra-sharma
#
# 771 found brute force https://muckrack.com/sofie-jackson
#
# 772 found brute force https://muckrack.com/kyle-olson
#
# 773 found brute force https://muckrack.com/ben-arthur
#
# 774 found brute force https://muckrack.com/louise-ayling
#
# 775 found tfidf https://muckrack.com/jonnyatawa
#
# 776 found brute force https://muckrack.com/sami-mokbel
#
# 777 found brute force https://muckrack.com/madanmohan-rao
#
# 778 found brute force https://muckrack.com/meghavi-singh
#
# 779 found brute force https://muckrack.com/jessie-lim
#
# 780 found tfidf https://muckrack.com/pete-loughlin
#
# 781 found brute force https://muckrack.com/adam-stites
#
# 782 found brute force https://muckrack.com/oscar-gonzalez
#
# 783 found brute force https://muckrack.com/randy-desoto
#
# 784 found brute force https://muckrack.com/john-carney
#
# 785 found brute force https://muckrack.com/emily-webber
#
# 786 found brute force https://muckrack.com/tyler-clifford
#
# 787 found brute force https://muckrack.com/jake-polden
#
# 788 found brute force https://muckrack.com/frank-bonner
#
# 789 found brute force https://muckrack.com/jay-rodriguez
#
# 790 found brute force https://muckrack.com/mark-douglas
#
# 791 found brute force https://muckrack.com/sian-babish
#
# 792 found brute force https://muckrack.com/david-cloninger
#
# 793 found brute force https://muckrack.com/sean-murray
#
# 794 found brute force https://muckrack.com/deborah-danan
#
# 795 found brute force https://muckrack.com/debjit-sinha
#
# 796 found brute force https://muckrack.com/ariane-sohrabi-shiraz
#
# 797 found brute force https://muckrack.com/norm-wood
#
# 798 found tfidf https://muckrack.com/ruey-yen
#
# 799 found brute force https://muckrack.com/gireesh-chandra-prasad
#
# 800 found brute force https://muckrack.com/andrew-prentice
#
# 801 found brute force https://muckrack.com/jason-wilde
#
# 802 found brute force https://muckrack.com/chris-walker
#
# 803 found brute force https://muckrack.com/paul-feely
#
# 804 found tfidf https://muckrack.com/ryan-duffy
#
# 805 found brute force https://muckrack.com/stephanie-linning
#
# 806 found brute force https://muckrack.com/nick-tyrrell
#
# 807 found brute force https://muckrack.com/damon-wilkinson
#
# 808 found brute force https://muckrack.com/danielle-haynes
#
# 809 found brute force https://muckrack.com/neil-munro
#
# 810 found brute force https://muckrack.com/eliza-mcphee
#
# 811 found tfidf https://muckrack.com/keithgroller
#
# 812 found brute force https://muckrack.com/jenzia-burgos
#
# 813 found brute force https://muckrack.com/anam-hamid
#
# 814 found brute force https://muckrack.com/zach-buckley
#
# 815 found brute force https://muckrack.com/sheldon-mickles
#
# 816 found brute force https://muckrack.com/joe-juliano
#
# 817 found tfidf https://muckrack.com/joeotterson
#
# 818 found brute force https://muckrack.com/donovan-jones
#
# 819 found brute force https://muckrack.com/gemma-jaleel
#
# 820 found brute force https://muckrack.com/caroline-blair
#
# 821 found brute force https://muckrack.com/max-winters
#
# 822 found brute force https://muckrack.com/scott-mendelson
#
# 823 found brute force https://muckrack.com/landon-stamper
#
# 824 found brute force https://muckrack.com/lauren-wise
#
# 825 found brute force https://muckrack.com/peerzada-abrar
#
# 826 found brute force https://muckrack.com/michael-austin
#
# 827 found brute force https://muckrack.com/mathew-davies
#
# 828 found brute force https://muckrack.com/hojun-choi
#
# 829 found brute force https://muckrack.com/bethany-bump
#
# 830 found brute force https://muckrack.com/tom-tapp
#
# 831 found brute force https://muckrack.com/gordon-kelly
#
# 832 found brute force https://muckrack.com/andrew-taylor
#
# 833 found brute force https://muckrack.com/helen-johnson
#
# 834 found brute force https://muckrack.com/jack-bezants
#
# 835 found brute force https://muckrack.com/clark-grell
#
# 836 found brute force https://muckrack.com/bob-unruh
#
# 837 found brute force https://muckrack.com/christopher-mckeon
#
# ...
#
# 3106 found brute force https://muckrack.com/ian-hughes
#
# 3107 found brute force https://muckrack.com/oliver-wright
#
# 3108 found brute force https://muckrack.com/steve-reed
#
# 3109 found brute force https://muckrack.com/pratishtha-nangia
#
# 3110 found brute force https://muckrack.com/chandini-monnappa
#
# 3111 found brute force https://muckrack.com/ellen-knickmeyer
#
# 3112 found brute force https://muckrack.com/jimmy-vielkind
#
# 3113 found brute force https://muckrack.com/emma-koehn
#
# 3114 found brute force https://muckrack.com/brad-cunningham
#
# 3115 found brute force https://muckrack.com/vinny-vella
#
# 3116 found brute force https://muckrack.com/jamie-hawkins
#
# 3117 found brute force https://muckrack.com/jamie-gardner
#
# 3118 found brute force https://muckrack.com/paul-hosford
#
# 3119 found brute force https://muckrack.com/james-nursey
# 3120 found brute force https://muckrack.com/emily-gosden
#
# 3121 found brute force https://muckrack.com/ananya-bhattacharya
#
# 3122 found brute force https://muckrack.com/ishita-ayan-dutt
#
# 3123 found brute force https://muckrack.com/wahyudi-soeriaatmadja
#
# 3124 found brute force https://muckrack.com/emma-gritt
#
# 3125 found brute force https://muckrack.com/sarah-brazendale
#
# 3126 found tfidf https://muckrack.com/jacob-carah
#
# 3127 found brute force https://muckrack.com/aby-sam-thomas
#
# 3128 found brute force https://muckrack.com/sarah-hodgson
#
# 3129 found brute force https://muckrack.com/eoin-english
#
# 3130 found brute force https://muckrack.com/peter-fitzsimons
#
# 3131 found brute force https://muckrack.com/aaron-sheldrick
#
# 3132 found brute force https://muckrack.com/sarah-lumley
#
# 3133 found brute force https://muckrack.com/georgia-diebelius
#
# 3134 found brute force https://muckrack.com/stephanie-kelly
#
# 3135 found brute force https://muckrack.com/sarah-obrien
#
# 3136 found brute force https://muckrack.com/joe-mcdonald
#
# 3137 found brute force https://muckrack.com/eryk-bagshaw
#
# 3138 found brute force https://muckrack.com/jim-derry
#
# 3139 found tfidf https://muckrack.com/al-bunch
#
# 3140 found brute force https://muckrack.com/emilia-bona
#
# 3141 found brute force https://muckrack.com/jane-kirby
#
# 3142 found brute force https://muckrack.com/sheryl-devore
#
# 3143 found brute force https://muckrack.com/eloise-marie-valadez
#
# 3144 found brute force https://muckrack.com/ed-white
#
# 3145 found brute force https://muckrack.com/paul-wiseman
#
# 3146 found brute force https://muckrack.com/tyler-sonnemaker
#
# 3147 found brute force https://muckrack.com/jessie-yeung
#
# 3148 found brute force https://muckrack.com/jessica-wade
#
# 3149 found brute force https://muckrack.com/elaine-kurtenbach
#
# 3150 found brute force https://muckrack.com/stephen-nellis
#
# 3151 found brute force https://muckrack.com/jeremy-clarkson
#
# 3152 found brute force https://muckrack.com/annie-nova
#
# 3153 found tfidf https://muckrack.com/piers-meyler
#
# 3154 found brute force https://muckrack.com/phillip-valys
#
# 3155 found brute force https://muckrack.com/vasily-zyryanov
#
# 3156 found brute force https://muckrack.com/ian-ransom
#
# 3157 found brute force https://muckrack.com/anneta-konstantinides
#
# 3158 found brute force https://muckrack.com/jenna-schiferl
#
# 3159 found brute force https://muckrack.com/abi-moustafa
#
# 3160 found brute force https://muckrack.com/eliza-relman
#
# 3161 found brute force https://muckrack.com/jeff-mason
#
# 3162 found brute force https://muckrack.com/jeannie-roberts
#
# 3163 found brute force https://muckrack.com/jason-meisner
#
# 3164 found brute force https://muckrack.com/victoria-allen
#
# 3165 found brute force https://muckrack.com/jason-barry
#
# 3166 found brute force https://muckrack.com/shiann-sivell
#
# 3167 found brute force https://muckrack.com/ellie-silverman
#
# 3168 found brute force https://muckrack.com/stephen-matthews
#
# 3169 found brute force https://muckrack.com/david-sanderson
#
# 3170 found brute force https://muckrack.com/andrew-gregory
#
# 3171 found brute force https://muckrack.com/nick-bonyhady
#
# 3172 found tfidf https://muckrack.com/robsheff
#
# 3173 found brute force https://muckrack.com/ciaran-kennedy
#
# 3174 found brute force https://muckrack.com/claire-bryan
#
# 3175 found brute force https://muckrack.com/rishabh-mansur
#
# 3176 found brute force https://muckrack.com/ritika-chopra
#
# 3177 found brute force https://muckrack.com/taylor-locke
#
# 3178 found brute force https://muckrack.com/ritvik-carvalho
#
# 3179 found brute force https://muckrack.com/taz-ali
#
# 3180 found brute force https://muckrack.com/michael-t-nietzel
#
# 3181 found brute force https://muckrack.com/conor-power
#
# 3182 found tfidf https://muckrack.com/michael-taylor-4
#
# 3183 found brute force https://muckrack.com/mick-zawislak
#
# 3184 found tfidf https://muckrack.com/libby_brooks
#
# 3185 found brute force https://muckrack.com/cara-anna
#
# 3186 found brute force https://muckrack.com/don-thompson
#
# 3187 found brute force https://muckrack.com/mikaela-porter
#
# 3188 found brute force https://muckrack.com/subrata-panda
#
# 3189 found brute force https://muckrack.com/avishek-g-dastidar
#
# 3190 found brute force https://muckrack.com/guy-hagi
#
# 3191 found brute force https://muckrack.com/rafael-guerrero
#
# 3192 found brute force https://muckrack.com/robert-channick
#
# 3193 found tfidf https://muckrack.com/frederick-rasmussen
#
# 3194 found tfidf https://muckrack.com/robertfeder
#
# 3195 found tfidf https://muckrack.com/lawrencehurley
#
# 3196 found brute force https://muckrack.com/lauren-valenti
#
# 3197 found brute force https://muckrack.com/radoslav-minkov
#
# 3198 found tfidf https://muckrack.com/robert-kidd
#
# 3199 found brute force https://muckrack.com/luke-powell
#
# 3200 found tfidf https://muckrack.com/rickey-dennis-jr
#
# 3201 found brute force https://muckrack.com/luz-moreno-lozano
#
# 3202 found brute force https://muckrack.com/carla-talbot
#
# 3203 found brute force https://muckrack.com/matthew-dessem
#
# 3204 found brute force https://muckrack.com/rebecca-lurye
#
# 3205 found brute force https://muckrack.com/rekha-balakrishnan
#
# 3206 found tfidf https://muckrack.com/matthew-belvedere
#
# 3207 found tfidf https://muckrack.com/matthew-belvedere
#
# 3208 found brute force https://muckrack.com/carrie-napoleon
#
# 3209 found brute force https://muckrack.com/rhett-morgan
#
# 3210 found brute force https://muckrack.com/svea-herbst-bayliss
#
# 3211 found tfidf https://muckrack.com/carolyn-cox
#
# 3212 found brute force https://muckrack.com/medha-singh
#
# 3213 found brute force https://muckrack.com/yuvraj-malik
#
# 3214 found brute force https://muckrack.com/chris-taylor
#
# 3215 found brute force https://muckrack.com/richard-caines
#
# 3216 found brute force https://muckrack.com/marc-jones
#
# 3217 found brute force https://muckrack.com/bryan-anderson
#
# 3218 found brute force https://muckrack.com/marc-bain
#
# 3219 found brute force https://muckrack.com/andrew-wagaman
#
# 3220 found brute force https://muckrack.com/susan-dunne
#
# 3221 found brute force https://muckrack.com/malik-asad
#
# 3222 found brute force https://muckrack.com/alex-lawler
#
# 3223 found brute force https://muckrack.com/madeline-fass
#
# 3224 found brute force https://muckrack.com/andy-bailey
#
# 3225 found brute force https://muckrack.com/mike-schneider
#
# 3226 found brute force https://muckrack.com/harmeet-kaur
#
# 3227 found brute force https://muckrack.com/mark-ballard
#
# 3228 found brute force https://muckrack.com/debarshi-dasgupta
#
# 3229 found brute force https://muckrack.com/laura-murphy-oates
#
# 3230 found brute force https://muckrack.com/larry-light
#
# 3231 found nothing https://muckrack.com/afdhel-aziz
#
# 3232 found brute force https://muckrack.com/rachel-askinasi
#
# 3233 found brute force https://muckrack.com/amelia-edelman
#
# 3234 found brute force https://muckrack.com/tom-ball
#
# 3235 found brute force https://muckrack.com/katie-hunt
#
# 3236 found brute force https://muckrack.com/charles-lussier
#
# 3237 found brute force https://muckrack.com/kathleen-christiansen
#
# 3238 found brute force https://muckrack.com/frank-olito
#
# 3239 found brute force https://muckrack.com/katherine-griffiths
#
# 3240 found tfidf https://muckrack.com/brian-orourke
#
# 3241 found brute force https://muckrack.com/neal-earley
#
# 3242 found brute force https://muckrack.com/garry-maddox
#
# 3243 found brute force https://muckrack.com/greg-baum
#
# 3244 found brute force https://muckrack.com/kate-aubusson
#
# 3245 found brute force https://muckrack.com/karl-quinn
#
# 3246 found brute force https://muckrack.com/kara-oneill
#
# 3247 found brute force https://muckrack.com/simon-duke
#
# 3248 found tfidf https://muckrack.com/barneyronay
#
# 3249 found brute force https://muckrack.com/kanika-datta
#
# 3250 found brute force https://muckrack.com/kaley-roshitsh
#
# 3251 found brute force https://muckrack.com/kaleigh-fasanella
#
# 3252 found brute force https://muckrack.com/kale-wilk
#
# 3253 found brute force https://muckrack.com/david-milliken
#
# 3254 found tfidf https://muckrack.com/april-jackson
#
# 3255 found brute force https://muckrack.com/rob-maaddi
#
# 3256 found brute force https://muckrack.com/tom-hutchison
#
# 3257 found tfidf https://muckrack.com/keithspera
#
# 3258 found brute force https://muckrack.com/keith-ridler
#
# 3259 found tfidf https://muckrack.com/todd-hamilton
#
# 3260 found brute force https://muckrack.com/phil-anastasia
# 3261 found brute force https://muckrack.com/kirsty-needham
#
# 3262 found brute force https://muckrack.com/mike-jones
#
# 3263 found brute force https://muckrack.com/lameez-omarjee
#
# 3264 found brute force https://muckrack.com/roisin-kelly
#
# 3265 found brute force https://muckrack.com/callum-keown
#
# 3266 found brute force https://muckrack.com/ashna-butani
#
# 3267 found brute force https://muckrack.com/daniel-jones
#
# 3268 found brute force https://muckrack.com/ashley-harding
#
# 3269 found brute force https://muckrack.com/kristen-lee
#
# 3270 found brute force https://muckrack.com/greg-wood
#
# 3271 found brute force https://muckrack.com/heather-osbourne
#
# 3272 found brute force https://muckrack.com/nandagopal-rajan
#
# 3273 found brute force https://muckrack.com/danyelle-khmara
#
# 3274 found brute force https://muckrack.com/christopher-tan
#
# 3275 found brute force https://muckrack.com/sindhu-sundar
#
# 3276 found brute force https://muckrack.com/cheryl-teh
#
# 3277 found tfidf https://muckrack.com/marissarothkopf
#
# 3278 found brute force https://muckrack.com/daniel-petrov
#
# 3279 found brute force https://muckrack.com/natalie-theodosi
#
# 3280 found brute force https://muckrack.com/alicia-petska
#
# 3281 found tfidf https://muckrack.com/kevinmyattwx
#
# 3282 found brute force https://muckrack.com/tim-reynolds
#
# 3283 found brute force https://muckrack.com/kevin-breuninger
#
# 3284 found brute force https://muckrack.com/russell-flannery
#
# 3285 found brute force https://muckrack.com/andy-hunter
#
# 3286 found brute force https://muckrack.com/ken-foxe
#
# 3287 found brute force https://muckrack.com/erin-parker
#
# 3288 found brute force https://muckrack.com/woody-paige
#
# 3289 found brute force https://muckrack.com/andrew-wagner
#
# 3290 found brute force https://muckrack.com/shannon-connellan
#
# 3291 found brute force https://muckrack.com/shamira-mccray
#
# 3292 found brute force https://muckrack.com/adam-beam
#
# 3293 found brute force https://muckrack.com/tim-mcdonnell
#
# 3294 found brute force https://muckrack.com/will-hodgkinson
#
# 3295 found brute force https://muckrack.com/steve-wollaston
#
# 3296 found nothing https://muckrack.com/tom-oates
#
# 3297 found brute force https://muckrack.com/tim-pearrell
#
# 3298 found brute force https://muckrack.com/tham-yuen-c
#
# 3299 found brute force https://muckrack.com/sophie-kitching
#
# 3300 found brute force https://muckrack.com/allison-collins
#
# 3301 found brute force https://muckrack.com/stuart-wilson
#
# 3302 found brute force https://muckrack.com/sourav-roy-barman
#
# 3303 found brute force https://muckrack.com/alexa-corse
#
# 3304 found tfidf https://muckrack.com/s-vaughan-nichols
#
# 3305 found brute force https://muckrack.com/steve-zalusky
#
# 3306 found brute force https://muckrack.com/alexandra-smith
#
# 3307 found brute force https://muckrack.com/wes-parnell
#
# 3308 found tfidf https://muckrack.com/alexiaer
#
# 3309 found brute force https://muckrack.com/steff-yotka
#
# 3310 found brute force https://muckrack.com/stephen-shankland
#
# 3311 found tfidf https://muckrack.com/stephen-orr
#
# 3312 found brute force https://muckrack.com/ali-hussain
#
# 3313 found brute force https://muckrack.com/alia-conley
#
# 3314 found brute force https://muckrack.com/stephen-losey
#
# 3315 found brute force https://muckrack.com/stephen-hudak
#
# 3316 found brute force https://muckrack.com/stephen-barry
#
# 3317 found brute force https://muckrack.com/stephanie-nebehay
#
# 3318 found brute force https://muckrack.com/amanda-hancock
#
# 3319 found brute force https://muckrack.com/tammy-mills
#
# 3320 found brute force https://muckrack.com/tammy-petersen
#
# 3321 found brute force https://muckrack.com/alan-sepinwall
#
# 3322 found brute force https://muckrack.com/warren-shoulberg
#
# 3323 found tfidf https://muckrack.com/wayne-witkowski
#
# 3324 found brute force https://muckrack.com/vivienne-aitken
#
# 3325 found brute force https://muckrack.com/amy-woodyatt
#
# 3326 found tfidf https://muckrack.com/veronica-cruz-1
#
# 3327 found brute force https://muckrack.com/abigail-hess
#
# 3328 found brute force https://muckrack.com/trevor-metcalfe
#
# 3329 found brute force https://muckrack.com/tracy-rucinski
#
# 3330 found brute force https://muckrack.com/tracy-carmichael
#
# 3331 found brute force https://muckrack.com/tracey-meyers
#
# 3332 found brute force https://muckrack.com/shruti-sonal
#
# 3333 found brute force https://muckrack.com/shubhodeep-chakravarty
#
# 3334 found brute force https://muckrack.com/tom-westbrook
#
# 3335 found brute force https://muckrack.com/tom-tuite
#
# 3336 found brute force https://muckrack.com/tom-payne
#
# 3337 found brute force https://muckrack.com/tom-cowie
#
# 3338 found brute force https://muckrack.com/timna-jacks
#
# 3339 found brute force https://muckrack.com/tim-gray
#
# 3340 found brute force https://muckrack.com/tim-graham
#
# 3341 found brute force https://muckrack.com/tiffini-theisen
#
# 3342 found brute force https://muckrack.com/skyler-swisher
#
# 3343 found brute force https://muckrack.com/geoffrey-morrison
#
# 3344 found brute force https://muckrack.com/michael-glackin
#
# 3345 found brute force https://muckrack.com/andrew-chamings
#
# 3346 found brute force https://muckrack.com/mark-robinson
#
# 3347 found brute force https://muckrack.com/lewis-smith
#
# 3348 found brute force https://muckrack.com/liam-mannix
#
# 3349 found brute force https://muckrack.com/lisa-maria-garza
#
# 3350 found brute force https://muckrack.com/lisa-vernon-sparks
#
# 3351 found brute force https://muckrack.com/lori-grunin
#
# 3352 found brute force https://muckrack.com/clyde-russell
#
# 3353 found brute force https://muckrack.com/megan-wyatt
#
# 3354 found brute force https://muckrack.com/marcus-hayes
#
# 3355 found brute force https://muckrack.com/christine-sexton
#
# 3356 found brute force https://muckrack.com/michelle-ng
#
# 3357 found brute force https://muckrack.com/mike-stobbe
#
# 3358 found brute force https://muckrack.com/mackenzie-sigalos
#
# 3359 found brute force https://muckrack.com/madeline-holcombe
#
# 3360 found brute force https://muckrack.com/mahealani-richardson
#
# 3361 found brute force https://muckrack.com/curtis-killman
#
# 3362 found brute force https://muckrack.com/leo-mckinstry
#
# 3363 found brute force https://muckrack.com/lea-salonga
#
# 3364 found brute force https://muckrack.com/lauren-feiner
#
# 3365 found brute force https://muckrack.com/laura-sanicola
#
# 3366 found brute force https://muckrack.com/laura-parnaby
#
# 3367 found brute force https://muckrack.com/laura-furr-mericas
#
# 3368 found brute force https://muckrack.com/della-hasselle
#
# 3369 found brute force https://muckrack.com/laird-borrelli-persson
#
# 3370 found brute force https://muckrack.com/leila-pitchford
#
# 3371 found brute force https://muckrack.com/leanne-italie
#
# 3372 found brute force https://muckrack.com/dan-gallagher
#
# 3373 found brute force https://muckrack.com/kyle-dawson
#
# 3374 found brute force https://muckrack.com/kriti-sonali
#
# 3375 found brute force https://muckrack.com/daniel-martin
#
# 3376 found brute force https://muckrack.com/kim-bell
#
# 3377 found tfidf https://muckrack.com/davealtimari
#
# 3378 found brute force https://muckrack.com/mahender-singh-manral

# %%
data.to_pickle('../Data/all_muckrack_links.pkl')

# %%
data
# Out:
#                 author  article_count                            request_url  \
# 0            Neil Shaw            523         https://muckrack.com/neil-shaw
# 1         James Rodger            512      https://muckrack.com/james-rodger
# 2           Jack Davis            251        https://muckrack.com/jack-davis
# 3           Adam Wells            223        https://muckrack.com/adam-wells
# 4        Sophie McCoid            218     https://muckrack.com/sophie-mccoid
# ...                ...            ...                                    ...
# 3833   Levi Sumagaysay             10   https://muckrack.com/levi-sumagaysay
# 3834       Ben Ashford             10       https://muckrack.com/ben-ashford
# 3835       Craig Brown             10       https://muckrack.com/craig-brown
# 3836  Courtney Connley             10  https://muckrack.com/courtney-connley
# 3837   MATTHEW PERRONE             10      https://muckrack.com/matthew-pera
#
#                                redirect_url       method confidence
# 0          https://muckrack.com/neil-shaw-1  brute force          -
# 1         https://muckrack.com/james-rodger  brute force          -
# 2           https://muckrack.com/jack-davis  brute force          -
# 3           https://muckrack.com/adam-wells  brute force          -
# 4        https://muckrack.com/sophie-mccoid  brute force          -
# ...                                     ...          ...        ...
# 3833   https://muckrack.com/levi-sumagaysay  brute force          -
# 3834       https://muckrack.com/ben-ashford  brute force          -
# 3835       https://muckrack.com/craig-brown  brute force          -
# 3836  https://muckrack.com/courtney-connley  brute force          -
# 3837      https://muckrack.com/matthew-pera  tfidf match       0.83
#
# [3838 rows x 6 columns]

# %%
data[data.request_url != data.redirect_url]
# Out:
#                              author  article_count  \
# 0                         Neil Shaw            523
# 7                        Simon Duke            214
# 13                      Rianne Addo            168
# 15          SA Editor Clark Schultz            161
# 16                     Lewis Winter            160
# ...                             ...            ...
# 3802                   Colin Kruger             10
# 3804                  Rafael Olmeda             10
# 3814            Rachel Koning Beals             10
# 3817        Corey Jones Tulsa World             10
# 3819  BLAKE PATERSON | Staff writer             10
#
#                                    request_url  \
# 0               https://muckrack.com/neil-shaw
# 7              https://muckrack.com/simon-duke
# 13            https://muckrack.com/rianne-addo
# 15          https://muckrack.com/clark-schultz
# 16           https://muckrack.com/lewis-winter
# ...                                        ...
# 3802         https://muckrack.com/colin-kruger
# 3804        https://muckrack.com/rafael-olmeda
# 3814  https://muckrack.com/rachel-koning-beals
# 3817          https://muckrack.com/corey-jones
# 3819       https://muckrack.com/blake-paterson
#
#                              redirect_url       method confidence
# 0        https://muckrack.com/neil-shaw-1  brute force          -
# 7     https://muckrack.com/simonduketimes  brute force          -
# 13        https://muckrack.com/rianneaddo  brute force          -
# 15      https://muckrack.com/clarkschultz  brute force          -
# 16      https://muckrack.com/lewisawinter  brute force          -
# ...                                   ...          ...        ...
# 3802    https://muckrack.com/colinjkruger  brute force          -
# 3804         https://muckrack.com/rolmeda  brute force          -
# 3814    https://muckrack.com/rachelkbeals  brute force          -
# 3817    https://muckrack.com/coreyhjones_  brute force          -
# 3819      https://muckrack.com/blakepater  brute force          -
#
# [486 rows x 6 columns]

# %%
urlopen(req).url

# %%
data[:100][data.request_url != data.redirect_url]
